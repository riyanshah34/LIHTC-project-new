# %% [markdown]
# ## Phase 1 - Georgia Transit Location Repository (Using Google Maps API )
#
# **1. Goal:**
#    To create a statewide dataset (`.csv`) of potential public transit stop and hub locations using the Google Places API.
#
# **2. Inputs:**
#     *   Google API Key.
#     *   Geographic Area Definition (Georgia Bounding Box).
#     *   List of relevant Transit Place Types (e.g., `bus_stop`, `subway_station`).
#     *   Grid search parameters (step size, search radius).
#
# **3. Outputs:**
#     *   `georgia_transit_locations_with_hub.csv`: A CSV file containing unique potential transit locations with their:
#         *   `place_id`
#         *   `name`
#         *   `latitude`
#         *   `longitude`
#         *   `types` (from Google API)
#         *   `vicinity`
#         *   `is_potential_hub` (boolean flag based on type/name rules).
#
# **4. Method:**
#     1.  Generate grid points covering Georgia.
#     2.  For each grid point, iterate through the specified list of transit `place_type`s.
#     3.  For each type, call the Google Places API (Nearby Search - Legacy) to find locations matching that `type` within the defined `radius`.
#     4.  Handle API pagination to retrieve multiple pages of results if necessary.
#     5.  For each result found:
#         *   Check if the `place_id` is already recorded (de-duplication).
#         *   If new, apply rules to determine `is_potential_hub`.
#         *   Add the location's details to a list.
#     6.  Periodically and finally, save the complete list of unique locations to the output CSV file.
#
# ---
#
# ## Code

# %%
import os
import re
import csv
import time
import requests
from datetime import datetime

# --- Configuration ---

API_KEY = "AIzaSyC5sawi_f7fI6X47XaKwUBFNvFRJq3VDJc"  
BASE_URL = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Timestamped output file to avoid overwrite
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
OUTPUT_FILE = f"georgia_transit_locations_with_hub_{timestamp}.csv"

# Bounding box over Georgia
MIN_LAT = 30.35
MAX_LAT = 35.00
MIN_LON = -85.60
MAX_LON = -80.84

# Grid and search settings
LAT_STEP = 0.08
LON_STEP = 0.08
RADIUS_METERS = 2000

# Transit types (query each separately)
PLACE_TYPES = [
    "bus_station", "bus_stop", "light_rail_station",
    "subway_station", "train_station", "transit_station"
]

# Rules for identifying "potential hubs"
HUB_INDICATING_TYPES = {"bus_station", "subway_station", "train_station", "transit_station"}
HUB_NAME_KEYWORDS_REGEX = re.compile(r'\b(station|center|hub)\b', re.IGNORECASE)

# Tracking sets and data
found_place_ids = set()
all_places_data = []

# --- Functions ---

def generate_grid_points(min_lat, max_lat, min_lon, max_lon, lat_step, lon_step):
    points = []
    lat = min_lat + lat_step / 2.0
    while lat < max_lat:
        lon = min_lon + lon_step / 2.0
        while lon < max_lon:
            points.append({"lat": lat, "lon": lon})
            lon += lon_step
        lat += lat_step
    return points

def fetch_nearby_places(lat, lon, radius, place_type, api_key, page_token=None):
    params = {
        "location": f"{lat},{lon}",
        "radius": radius,
        "type": place_type,
        "key": api_key,
    }
    if page_token:
        params["pagetoken"] = page_token
        time.sleep(2)  # Required delay for next_page_token

    try:
        response = requests.get(BASE_URL, params=params, timeout=10)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {place_type} at {lat:.4f},{lon:.4f}: {e}")
        return None

def check_potential_hub(place_types_list, place_name):
    if HUB_INDICATING_TYPES.intersection(place_types_list):
        return True
    if place_name and HUB_NAME_KEYWORDS_REGEX.search(place_name):
        return True
    return False

def save_progress(filename, data):
    try:
        if data:
            fieldnames = data[0].keys()
            with open(filename, 'w', newline='', encoding='utf-8') as f_out:
                writer = csv.DictWriter(f_out, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(data)
            print(f"Progress saved: {len(data)} places → {filename}")
        else:
            print("No data to save yet.")
    except IOError as e:
        print(f"Error writing file: {e}")

# --- Main Execution ---

print("Generating grid points...")
grid_points = generate_grid_points(MIN_LAT, MAX_LAT, MIN_LON, MAX_LON, LAT_STEP, LON_STEP)
print(f"Total grid points to search: {len(grid_points)}\n")

for i, point in enumerate(grid_points):
    print(f"\n--- Grid Point {i+1}/{len(grid_points)} — ({point['lat']:.4f}, {point['lon']:.4f}) ---")
    grid_point_new_places = 0

    for place_type in PLACE_TYPES:
        next_page_token = None

        while True:
            results_json = fetch_nearby_places(
                point["lat"], point["lon"], RADIUS_METERS, place_type, API_KEY, next_page_token
            )

            if results_json and results_json.get("status") == "OK":
                for place in results_json.get("results", []):
                    place_id = place.get("place_id")
                    if place_id and place_id not in found_place_ids:
                        found_place_ids.add(place_id)
                        place_name = place.get("name", "")
                        place_types_list = place.get("types", [])

                        is_hub = check_potential_hub(set(place_types_list), place_name)

                        place_data = {
                            "place_id": place_id,
                            "name": place_name,
                            "latitude": place.get("geometry", {}).get("location", {}).get("lat", ""),
                            "longitude": place.get("geometry", {}).get("location", {}).get("lng", ""),
                            "types": ";".join(place_types_list),
                            "vicinity": place.get("vicinity", ""),
                            "is_potential_hub": is_hub,
                            "source_type": place_type,
                        }
                        all_places_data.append(place_data)
                        grid_point_new_places += 1

                next_page_token = results_json.get("next_page_token")
                if not next_page_token:
                    break
            elif results_json and results_json.get("status") == "OVER_QUERY_LIMIT":
                print("⚠️ Rate limit hit. Sleeping 60 seconds...")
                time.sleep(60)
                continue
            else:
                break

    print(f"New places found at this point: {grid_point_new_places}")

    time.sleep(0.2)

    if (i + 1) % 10 == 0:
        print(f"\n💾 [Checkpoint] Saving progress at {i+1} grid points...")
        save_progress(OUTPUT_FILE, all_places_data)

# --- Final Save ---

print(f"\ninished all grid points. Total unique places found: {len(all_places_data)}")
print("Saving final results...")
save_progress(OUTPUT_FILE, all_places_data)
print("🎉 Done.")
# Out:
# Generating grid points...
# Total grid points to search: 3480
#
#
# --- Grid Point 1/3480 — (30.3900, -85.5600) ---
# New places found at this point: 4
#
# --- Grid Point 2/3480 — (30.3900, -85.4800) ---
# New places found at this point: 0
#
# --- Grid Point 3/3480 — (30.3900, -85.4000) ---
# New places found at this point: 1
#
# --- Grid Point 4/3480 — (30.3900, -85.3200) ---
# New places found at this point: 0
#
# --- Grid Point 5/3480 — (30.3900, -85.2400) ---
# New places found at this point: 0
#
# --- Grid Point 6/3480 — (30.3900, -85.1600) ---
# New places found at this point: 2
#
# --- Grid Point 7/3480 — (30.3900, -85.0800) ---
# New places found at this point: 1
#
# --- Grid Point 8/3480 — (30.3900, -85.0000) ---
# New places found at this point: 1
#
# --- Grid Point 9/3480 — (30.3900, -84.9200) ---
# New places found at this point: 0
#
# --- Grid Point 10/3480 — (30.3900, -84.8400) ---
# New places found at this point: 1
#
# 💾 [Checkpoint] Saving progress at 10 grid points...
# Progress saved: 10 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 11/3480 — (30.3900, -84.7600) ---
# New places found at this point: 0
#
# --- Grid Point 12/3480 — (30.3900, -84.6800) ---
# New places found at this point: 6
#
# --- Grid Point 13/3480 — (30.3900, -84.6000) ---
# New places found at this point: 9
#
# --- Grid Point 14/3480 — (30.3900, -84.5200) ---
# New places found at this point: 1
#
# --- Grid Point 15/3480 — (30.3900, -84.4400) ---
# New places found at this point: 0
#
# --- Grid Point 16/3480 — (30.3900, -84.3600) ---
# New places found at this point: 34
#
# --- Grid Point 17/3480 — (30.3900, -84.2800) ---
# New places found at this point: 94
#
# --- Grid Point 18/3480 — (30.3900, -84.2000) ---
# New places found at this point: 23
#
# --- Grid Point 19/3480 — (30.3900, -84.1200) ---
# New places found at this point: 26
#
# --- Grid Point 20/3480 — (30.3900, -84.0400) ---
# New places found at this point: 2
#
# 💾 [Checkpoint] Saving progress at 20 grid points...
# Progress saved: 205 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 21/3480 — (30.3900, -83.9600) ---
# New places found at this point: 1
#
# --- Grid Point 22/3480 — (30.3900, -83.8800) ---
# New places found at this point: 0
#
# --- Grid Point 23/3480 — (30.3900, -83.8000) ---
# New places found at this point: 11
#
# --- Grid Point 24/3480 — (30.3900, -83.7200) ---
# New places found at this point: 1
#
# --- Grid Point 25/3480 — (30.3900, -83.6400) ---
# New places found at this point: 2
#
# --- Grid Point 26/3480 — (30.3900, -83.5600) ---
# New places found at this point: 0
#
# --- Grid Point 27/3480 — (30.3900, -83.4800) ---
# New places found at this point: 2
#
# --- Grid Point 28/3480 — (30.3900, -83.4000) ---
# New places found at this point: 1
#
# --- Grid Point 29/3480 — (30.3900, -83.3200) ---
# New places found at this point: 5
#
# --- Grid Point 30/3480 — (30.3900, -83.2400) ---
# New places found at this point: 4
#
# 💾 [Checkpoint] Saving progress at 30 grid points...
# Progress saved: 232 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 31/3480 — (30.3900, -83.1600) ---
# New places found at this point: 25
#
# --- Grid Point 32/3480 — (30.3900, -83.0800) ---
# New places found at this point: 2
#
# --- Grid Point 33/3480 — (30.3900, -83.0000) ---
# New places found at this point: 3
#
# --- Grid Point 34/3480 — (30.3900, -82.9200) ---
# New places found at this point: 11
#
# --- Grid Point 35/3480 — (30.3900, -82.8400) ---
# New places found at this point: 4
#
# --- Grid Point 36/3480 — (30.3900, -82.7600) ---
# New places found at this point: 2
#
# --- Grid Point 37/3480 — (30.3900, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 38/3480 — (30.3900, -82.6000) ---
# New places found at this point: 1
#
# --- Grid Point 39/3480 — (30.3900, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 40/3480 — (30.3900, -82.4400) ---
# New places found at this point: 1
#
# 💾 [Checkpoint] Saving progress at 40 grid points...
# Progress saved: 281 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 41/3480 — (30.3900, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 42/3480 — (30.3900, -82.2800) ---
# New places found at this point: 0
#
# --- Grid Point 43/3480 — (30.3900, -82.2000) ---
# New places found at this point: 3
#
# --- Grid Point 44/3480 — (30.3900, -82.1200) ---
# New places found at this point: 5
#
# --- Grid Point 45/3480 — (30.3900, -82.0400) ---
# New places found at this point: 2
#
# --- Grid Point 46/3480 — (30.3900, -81.9600) ---
# New places found at this point: 2
#
# --- Grid Point 47/3480 — (30.3900, -81.8800) ---
# New places found at this point: 3
#
# --- Grid Point 48/3480 — (30.3900, -81.8000) ---
# New places found at this point: 47
#
# --- Grid Point 49/3480 — (30.3900, -81.7200) ---
# New places found at this point: 118
#
# --- Grid Point 50/3480 — (30.3900, -81.6400) ---
# New places found at this point: 79
#
# 💾 [Checkpoint] Saving progress at 50 grid points...
# Progress saved: 540 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 51/3480 — (30.3900, -81.5600) ---
# New places found at this point: 27
#
# --- Grid Point 52/3480 — (30.3900, -81.4800) ---
# New places found at this point: 29
#
# --- Grid Point 53/3480 — (30.3900, -81.4000) ---
# New places found at this point: 67
#
# --- Grid Point 54/3480 — (30.3900, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 55/3480 — (30.3900, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 56/3480 — (30.3900, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 57/3480 — (30.3900, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 58/3480 — (30.3900, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 59/3480 — (30.3900, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 60/3480 — (30.3900, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 60 grid points...
# Progress saved: 663 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 61/3480 — (30.4700, -85.5600) ---
# New places found at this point: 3
#
# --- Grid Point 62/3480 — (30.4700, -85.4800) ---
# New places found at this point: 9
#
# --- Grid Point 63/3480 — (30.4700, -85.4000) ---
# New places found at this point: 5
#
# --- Grid Point 64/3480 — (30.4700, -85.3200) ---
# New places found at this point: 0
#
# --- Grid Point 65/3480 — (30.4700, -85.2400) ---
# New places found at this point: 0
#
# --- Grid Point 66/3480 — (30.4700, -85.1600) ---
# New places found at this point: 5
#
# --- Grid Point 67/3480 — (30.4700, -85.0800) ---
# New places found at this point: 3
#
# --- Grid Point 68/3480 — (30.4700, -85.0000) ---
# New places found at this point: 1
#
# --- Grid Point 69/3480 — (30.4700, -84.9200) ---
# New places found at this point: 0
#
# --- Grid Point 70/3480 — (30.4700, -84.8400) ---
# New places found at this point: 1
#
# 💾 [Checkpoint] Saving progress at 70 grid points...
# Progress saved: 690 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 71/3480 — (30.4700, -84.7600) ---
# New places found at this point: 0
#
# --- Grid Point 72/3480 — (30.4700, -84.6800) ---
# New places found at this point: 0
#
# --- Grid Point 73/3480 — (30.4700, -84.6000) ---
# New places found at this point: 7
#
# --- Grid Point 74/3480 — (30.4700, -84.5200) ---
# New places found at this point: 2
#
# --- Grid Point 75/3480 — (30.4700, -84.4400) ---
# New places found at this point: 4
#
# --- Grid Point 76/3480 — (30.4700, -84.3600) ---
# New places found at this point: 108
#
# --- Grid Point 77/3480 — (30.4700, -84.2800) ---
# New places found at this point: 125
#
# --- Grid Point 78/3480 — (30.4700, -84.2000) ---
# New places found at this point: 62
#
# --- Grid Point 79/3480 — (30.4700, -84.1200) ---
# New places found at this point: 38
#
# --- Grid Point 80/3480 — (30.4700, -84.0400) ---
# New places found at this point: 21
#
# 💾 [Checkpoint] Saving progress at 80 grid points...
# Progress saved: 1057 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 81/3480 — (30.4700, -83.9600) ---
# New places found at this point: 9
#
# --- Grid Point 82/3480 — (30.4700, -83.8800) ---
# New places found at this point: 30
#
# --- Grid Point 83/3480 — (30.4700, -83.8000) ---
# New places found at this point: 0
#
# --- Grid Point 84/3480 — (30.4700, -83.7200) ---
# New places found at this point: 1
#
# --- Grid Point 85/3480 — (30.4700, -83.6400) ---
# New places found at this point: 52
#
# --- Grid Point 86/3480 — (30.4700, -83.5600) ---
# New places found at this point: 0
#
# --- Grid Point 87/3480 — (30.4700, -83.4800) ---
# New places found at this point: 0
#
# --- Grid Point 88/3480 — (30.4700, -83.4000) ---
# New places found at this point: 77
#
# --- Grid Point 89/3480 — (30.4700, -83.3200) ---
# New places found at this point: 5
#
# --- Grid Point 90/3480 — (30.4700, -83.2400) ---
# New places found at this point: 12
#
# 💾 [Checkpoint] Saving progress at 90 grid points...
# Progress saved: 1243 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 91/3480 — (30.4700, -83.1600) ---
# New places found at this point: 0
#
# --- Grid Point 92/3480 — (30.4700, -83.0800) ---
# New places found at this point: 3
#
# --- Grid Point 93/3480 — (30.4700, -83.0000) ---
# New places found at this point: 0
#
# --- Grid Point 94/3480 — (30.4700, -82.9200) ---
# New places found at this point: 16
#
# --- Grid Point 95/3480 — (30.4700, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 96/3480 — (30.4700, -82.7600) ---
# Error fetching transit_station at 30.4700,-82.7600: 500 Server Error: Internal Server Error for url: https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.47%2C-82.76000000000005&radius=2000&type=transit_station&key=AIzaSyC5sawi_f7fI6X47XaKwUBFNvFRJq3VDJc
# New places found at this point: 0
#
# --- Grid Point 97/3480 — (30.4700, -82.6800) ---
# New places found at this point: 1
#
# --- Grid Point 98/3480 — (30.4700, -82.6000) ---
# New places found at this point: 0
#
# --- Grid Point 99/3480 — (30.4700, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 100/3480 — (30.4700, -82.4400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 100 grid points...
# Progress saved: 1263 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 101/3480 — (30.4700, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 102/3480 — (30.4700, -82.2800) ---
# New places found at this point: 1
#
# --- Grid Point 103/3480 — (30.4700, -82.2000) ---
# New places found at this point: 8
#
# --- Grid Point 104/3480 — (30.4700, -82.1200) ---
# New places found at this point: 0
#
# --- Grid Point 105/3480 — (30.4700, -82.0400) ---
# New places found at this point: 1
#
# --- Grid Point 106/3480 — (30.4700, -81.9600) ---
# New places found at this point: 0
#
# --- Grid Point 107/3480 — (30.4700, -81.8800) ---
# New places found at this point: 0
#
# --- Grid Point 108/3480 — (30.4700, -81.8000) ---
# New places found at this point: 13
#
# --- Grid Point 109/3480 — (30.4700, -81.7200) ---
# New places found at this point: 15
#
# --- Grid Point 110/3480 — (30.4700, -81.6400) ---
# New places found at this point: 63
#
# 💾 [Checkpoint] Saving progress at 110 grid points...
# Progress saved: 1364 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 111/3480 — (30.4700, -81.5600) ---
# New places found at this point: 58
#
# --- Grid Point 112/3480 — (30.4700, -81.4800) ---
# New places found at this point: 18
#
# --- Grid Point 113/3480 — (30.4700, -81.4000) ---
# New places found at this point: 1
#
# --- Grid Point 114/3480 — (30.4700, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 115/3480 — (30.4700, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 116/3480 — (30.4700, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 117/3480 — (30.4700, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 118/3480 — (30.4700, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 119/3480 — (30.4700, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 120/3480 — (30.4700, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 120 grid points...
# Progress saved: 1441 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 121/3480 — (30.5500, -85.5600) ---
# New places found at this point: 5
#
# --- Grid Point 122/3480 — (30.5500, -85.4800) ---
# New places found at this point: 1
#
# --- Grid Point 123/3480 — (30.5500, -85.4000) ---
# New places found at this point: 10
#
# --- Grid Point 124/3480 — (30.5500, -85.3200) ---
# New places found at this point: 1
#
# --- Grid Point 125/3480 — (30.5500, -85.2400) ---
# New places found at this point: 1
#
# --- Grid Point 126/3480 — (30.5500, -85.1600) ---
# New places found at this point: 7
#
# --- Grid Point 127/3480 — (30.5500, -85.0800) ---
# New places found at this point: 0
#
# --- Grid Point 128/3480 — (30.5500, -85.0000) ---
# New places found at this point: 0
#
# --- Grid Point 129/3480 — (30.5500, -84.9200) ---
# New places found at this point: 2
#
# --- Grid Point 130/3480 — (30.5500, -84.8400) ---
# New places found at this point: 1
#
# 💾 [Checkpoint] Saving progress at 130 grid points...
# Progress saved: 1469 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 131/3480 — (30.5500, -84.7600) ---
# New places found at this point: 8
#
# --- Grid Point 132/3480 — (30.5500, -84.6800) ---
# New places found at this point: 10
#
# --- Grid Point 133/3480 — (30.5500, -84.6000) ---
# New places found at this point: 60
#
# --- Grid Point 134/3480 — (30.5500, -84.5200) ---
# New places found at this point: 10
#
# --- Grid Point 135/3480 — (30.5500, -84.4400) ---
# New places found at this point: 4
#
# --- Grid Point 136/3480 — (30.5500, -84.3600) ---
# New places found at this point: 25
#
# --- Grid Point 137/3480 — (30.5500, -84.2800) ---
# New places found at this point: 39
#
# --- Grid Point 138/3480 — (30.5500, -84.2000) ---
# New places found at this point: 59
#
# --- Grid Point 139/3480 — (30.5500, -84.1200) ---
# New places found at this point: 17
#
# --- Grid Point 140/3480 — (30.5500, -84.0400) ---
# New places found at this point: 9
#
# 💾 [Checkpoint] Saving progress at 140 grid points...
# Progress saved: 1710 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 141/3480 — (30.5500, -83.9600) ---
# New places found at this point: 0
#
# --- Grid Point 142/3480 — (30.5500, -83.8800) ---
# New places found at this point: 61
#
# --- Grid Point 143/3480 — (30.5500, -83.8000) ---
# New places found at this point: 4
#
# --- Grid Point 144/3480 — (30.5500, -83.7200) ---
# New places found at this point: 0
#
# --- Grid Point 145/3480 — (30.5500, -83.6400) ---
# New places found at this point: 1
#
# --- Grid Point 146/3480 — (30.5500, -83.5600) ---
# New places found at this point: 4
#
# --- Grid Point 147/3480 — (30.5500, -83.4800) ---
# New places found at this point: 2
#
# --- Grid Point 148/3480 — (30.5500, -83.4000) ---
# New places found at this point: 4
#
# --- Grid Point 149/3480 — (30.5500, -83.3200) ---
# New places found at this point: 0
#
# --- Grid Point 150/3480 — (30.5500, -83.2400) ---
# New places found at this point: 2
#
# 💾 [Checkpoint] Saving progress at 150 grid points...
# Progress saved: 1788 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 151/3480 — (30.5500, -83.1600) ---
# New places found at this point: 3
#
# --- Grid Point 152/3480 — (30.5500, -83.0800) ---
# New places found at this point: 6
#
# --- Grid Point 153/3480 — (30.5500, -83.0000) ---
# New places found at this point: 2
#
# --- Grid Point 154/3480 — (30.5500, -82.9200) ---
# New places found at this point: 0
#
# --- Grid Point 155/3480 — (30.5500, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 156/3480 — (30.5500, -82.7600) ---
# New places found at this point: 0
#
# --- Grid Point 157/3480 — (30.5500, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 158/3480 — (30.5500, -82.6000) ---
# New places found at this point: 0
#
# --- Grid Point 159/3480 — (30.5500, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 160/3480 — (30.5500, -82.4400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 160 grid points...
# Progress saved: 1799 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 161/3480 — (30.5500, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 162/3480 — (30.5500, -82.2800) ---
# New places found at this point: 0
#
# --- Grid Point 163/3480 — (30.5500, -82.2000) ---
# New places found at this point: 0
#
# --- Grid Point 164/3480 — (30.5500, -82.1200) ---
# New places found at this point: 0
#
# --- Grid Point 165/3480 — (30.5500, -82.0400) ---
# New places found at this point: 2
#
# --- Grid Point 166/3480 — (30.5500, -81.9600) ---
# New places found at this point: 3
#
# --- Grid Point 167/3480 — (30.5500, -81.8800) ---
# New places found at this point: 8
#
# --- Grid Point 168/3480 — (30.5500, -81.8000) ---
# New places found at this point: 40
#
# --- Grid Point 169/3480 — (30.5500, -81.7200) ---
# New places found at this point: 13
#
# --- Grid Point 170/3480 — (30.5500, -81.6400) ---
# New places found at this point: 3
#
# 💾 [Checkpoint] Saving progress at 170 grid points...
# Progress saved: 1868 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 171/3480 — (30.5500, -81.5600) ---
# New places found at this point: 17
#
# --- Grid Point 172/3480 — (30.5500, -81.4800) ---
# New places found at this point: 5
#
# --- Grid Point 173/3480 — (30.5500, -81.4000) ---
# New places found at this point: 0
#
# --- Grid Point 174/3480 — (30.5500, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 175/3480 — (30.5500, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 176/3480 — (30.5500, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 177/3480 — (30.5500, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 178/3480 — (30.5500, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 179/3480 — (30.5500, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 180/3480 — (30.5500, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 180 grid points...
# Progress saved: 1890 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 181/3480 — (30.6300, -85.5600) ---
# New places found at this point: 6
#
# --- Grid Point 182/3480 — (30.6300, -85.4800) ---
# New places found at this point: 6
#
# --- Grid Point 183/3480 — (30.6300, -85.4000) ---
# New places found at this point: 7
#
# --- Grid Point 184/3480 — (30.6300, -85.3200) ---
# New places found at this point: 1
#
# --- Grid Point 185/3480 — (30.6300, -85.2400) ---
# New places found at this point: 1
#
# --- Grid Point 186/3480 — (30.6300, -85.1600) ---
# New places found at this point: 6
#
# --- Grid Point 187/3480 — (30.6300, -85.0800) ---
# New places found at this point: 2
#
# --- Grid Point 188/3480 — (30.6300, -85.0000) ---
# New places found at this point: 6
#
# --- Grid Point 189/3480 — (30.6300, -84.9200) ---
# New places found at this point: 3
#
# --- Grid Point 190/3480 — (30.6300, -84.8400) ---
# New places found at this point: 2
#
# 💾 [Checkpoint] Saving progress at 190 grid points...
# Progress saved: 1930 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 191/3480 — (30.6300, -84.7600) ---
# New places found at this point: 3
#
# --- Grid Point 192/3480 — (30.6300, -84.6800) ---
# New places found at this point: 17
#
# --- Grid Point 193/3480 — (30.6300, -84.6000) ---
# New places found at this point: 4
#
# --- Grid Point 194/3480 — (30.6300, -84.5200) ---
# New places found at this point: 5
#
# --- Grid Point 195/3480 — (30.6300, -84.4400) ---
# New places found at this point: 20
#
# --- Grid Point 196/3480 — (30.6300, -84.3600) ---
# New places found at this point: 6
#
# --- Grid Point 197/3480 — (30.6300, -84.2800) ---
# New places found at this point: 8
#
# --- Grid Point 198/3480 — (30.6300, -84.2000) ---
# New places found at this point: 4
#
# --- Grid Point 199/3480 — (30.6300, -84.1200) ---
# New places found at this point: 3
#
# --- Grid Point 200/3480 — (30.6300, -84.0400) ---
# New places found at this point: 4
#
# 💾 [Checkpoint] Saving progress at 200 grid points...
# Progress saved: 2004 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 201/3480 — (30.6300, -83.9600) ---
# New places found at this point: 0
#
# --- Grid Point 202/3480 — (30.6300, -83.8800) ---
# New places found at this point: 5
#
# --- Grid Point 203/3480 — (30.6300, -83.8000) ---
# New places found at this point: 0
#
# --- Grid Point 204/3480 — (30.6300, -83.7200) ---
# New places found at this point: 1
#
# --- Grid Point 205/3480 — (30.6300, -83.6400) ---
# New places found at this point: 3
#
# --- Grid Point 206/3480 — (30.6300, -83.5600) ---
# New places found at this point: 0
#
# --- Grid Point 207/3480 — (30.6300, -83.4800) ---
# New places found at this point: 3
#
# --- Grid Point 208/3480 — (30.6300, -83.4000) ---
# New places found at this point: 3
#
# --- Grid Point 209/3480 — (30.6300, -83.3200) ---
# New places found at this point: 4
#
# --- Grid Point 210/3480 — (30.6300, -83.2400) ---
# New places found at this point: 3
#
# 💾 [Checkpoint] Saving progress at 210 grid points...
# Progress saved: 2026 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 211/3480 — (30.6300, -83.1600) ---
# New places found at this point: 3
#
# --- Grid Point 212/3480 — (30.6300, -83.0800) ---
# New places found at this point: 2
#
# --- Grid Point 213/3480 — (30.6300, -83.0000) ---
# New places found at this point: 0
#
# --- Grid Point 214/3480 — (30.6300, -82.9200) ---
# New places found at this point: 0
#
# --- Grid Point 215/3480 — (30.6300, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 216/3480 — (30.6300, -82.7600) ---
# New places found at this point: 0
#
# --- Grid Point 217/3480 — (30.6300, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 218/3480 — (30.6300, -82.6000) ---
# New places found at this point: 0
#
# --- Grid Point 219/3480 — (30.6300, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 220/3480 — (30.6300, -82.4400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 220 grid points...
# Progress saved: 2031 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 221/3480 — (30.6300, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 222/3480 — (30.6300, -82.2800) ---
# New places found at this point: 0
#
# --- Grid Point 223/3480 — (30.6300, -82.2000) ---
# New places found at this point: 0
#
# --- Grid Point 224/3480 — (30.6300, -82.1200) ---
# New places found at this point: 0
#
# --- Grid Point 225/3480 — (30.6300, -82.0400) ---
# New places found at this point: 1
#
# --- Grid Point 226/3480 — (30.6300, -81.9600) ---
# New places found at this point: 0
#
# --- Grid Point 227/3480 — (30.6300, -81.8800) ---
# New places found at this point: 9
#
# --- Grid Point 228/3480 — (30.6300, -81.8000) ---
# New places found at this point: 8
#
# --- Grid Point 229/3480 — (30.6300, -81.7200) ---
# New places found at this point: 5
#
# --- Grid Point 230/3480 — (30.6300, -81.6400) ---
# New places found at this point: 60
#
# 💾 [Checkpoint] Saving progress at 230 grid points...
# Progress saved: 2114 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 231/3480 — (30.6300, -81.5600) ---
# New places found at this point: 61
#
# --- Grid Point 232/3480 — (30.6300, -81.4800) ---
# New places found at this point: 60
#
# --- Grid Point 233/3480 — (30.6300, -81.4000) ---
# New places found at this point: 0
#
# --- Grid Point 234/3480 — (30.6300, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 235/3480 — (30.6300, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 236/3480 — (30.6300, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 237/3480 — (30.6300, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 238/3480 — (30.6300, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 239/3480 — (30.6300, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 240/3480 — (30.6300, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 240 grid points...
# Progress saved: 2235 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 241/3480 — (30.7100, -85.5600) ---
# New places found at this point: 8
#
# --- Grid Point 242/3480 — (30.7100, -85.4800) ---
# New places found at this point: 6
#
# --- Grid Point 243/3480 — (30.7100, -85.4000) ---
# New places found at this point: 28
#
# --- Grid Point 244/3480 — (30.7100, -85.3200) ---
# New places found at this point: 6
#
# --- Grid Point 245/3480 — (30.7100, -85.2400) ---
# New places found at this point: 9
#
# --- Grid Point 246/3480 — (30.7100, -85.1600) ---
# New places found at this point: 6
#
# --- Grid Point 247/3480 — (30.7100, -85.0800) ---
# New places found at this point: 14
#
# --- Grid Point 248/3480 — (30.7100, -85.0000) ---
# New places found at this point: 22
#
# --- Grid Point 249/3480 — (30.7100, -84.9200) ---
# New places found at this point: 60
#
# --- Grid Point 250/3480 — (30.7100, -84.8400) ---
# New places found at this point: 61
#
# 💾 [Checkpoint] Saving progress at 250 grid points...
# Progress saved: 2455 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 251/3480 — (30.7100, -84.7600) ---
# New places found at this point: 4
#
# --- Grid Point 252/3480 — (30.7100, -84.6800) ---
# New places found at this point: 3
#
# --- Grid Point 253/3480 — (30.7100, -84.6000) ---
# New places found at this point: 3
#
# --- Grid Point 254/3480 — (30.7100, -84.5200) ---
# New places found at this point: 4
#
# --- Grid Point 255/3480 — (30.7100, -84.4400) ---
# New places found at this point: 1
#
# --- Grid Point 256/3480 — (30.7100, -84.3600) ---
# New places found at this point: 14
#
# --- Grid Point 257/3480 — (30.7100, -84.2800) ---
# New places found at this point: 2
#
# --- Grid Point 258/3480 — (30.7100, -84.2000) ---
# New places found at this point: 5
#
# --- Grid Point 259/3480 — (30.7100, -84.1200) ---
# New places found at this point: 13
#
# --- Grid Point 260/3480 — (30.7100, -84.0400) ---
# New places found at this point: 2
#
# 💾 [Checkpoint] Saving progress at 260 grid points...
# Progress saved: 2506 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 261/3480 — (30.7100, -83.9600) ---
# New places found at this point: 1
#
# --- Grid Point 262/3480 — (30.7100, -83.8800) ---
# New places found at this point: 3
#
# --- Grid Point 263/3480 — (30.7100, -83.8000) ---
# New places found at this point: 0
#
# --- Grid Point 264/3480 — (30.7100, -83.7200) ---
# New places found at this point: 2
#
# --- Grid Point 265/3480 — (30.7100, -83.6400) ---
# New places found at this point: 1
#
# --- Grid Point 266/3480 — (30.7100, -83.5600) ---
# New places found at this point: 2
#
# --- Grid Point 267/3480 — (30.7100, -83.4800) ---
# New places found at this point: 0
#
# --- Grid Point 268/3480 — (30.7100, -83.4000) ---
# New places found at this point: 1
#
# --- Grid Point 269/3480 — (30.7100, -83.3200) ---
# New places found at this point: 39
#
# --- Grid Point 270/3480 — (30.7100, -83.2400) ---
# New places found at this point: 7
#
# 💾 [Checkpoint] Saving progress at 270 grid points...
# Progress saved: 2562 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 271/3480 — (30.7100, -83.1600) ---
# New places found at this point: 4
#
# --- Grid Point 272/3480 — (30.7100, -83.0800) ---
# New places found at this point: 6
#
# --- Grid Point 273/3480 — (30.7100, -83.0000) ---
# New places found at this point: 3
#
# --- Grid Point 274/3480 — (30.7100, -82.9200) ---
# New places found at this point: 0
#
# --- Grid Point 275/3480 — (30.7100, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 276/3480 — (30.7100, -82.7600) ---
# New places found at this point: 0
#
# --- Grid Point 277/3480 — (30.7100, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 278/3480 — (30.7100, -82.6000) ---
# New places found at this point: 2
#
# --- Grid Point 279/3480 — (30.7100, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 280/3480 — (30.7100, -82.4400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 280 grid points...
# Progress saved: 2577 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 281/3480 — (30.7100, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 282/3480 — (30.7100, -82.2800) ---
# New places found at this point: 0
#
# --- Grid Point 283/3480 — (30.7100, -82.2000) ---
# New places found at this point: 0
#
# --- Grid Point 284/3480 — (30.7100, -82.1200) ---
# New places found at this point: 0
#
# --- Grid Point 285/3480 — (30.7100, -82.0400) ---
# New places found at this point: 4
#
# --- Grid Point 286/3480 — (30.7100, -81.9600) ---
# New places found at this point: 1
#
# --- Grid Point 287/3480 — (30.7100, -81.8800) ---
# New places found at this point: 1
#
# --- Grid Point 288/3480 — (30.7100, -81.8000) ---
# New places found at this point: 1
#
# --- Grid Point 289/3480 — (30.7100, -81.7200) ---
# New places found at this point: 2
#
# --- Grid Point 290/3480 — (30.7100, -81.6400) ---
# New places found at this point: 1
#
# 💾 [Checkpoint] Saving progress at 290 grid points...
# Progress saved: 2587 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 291/3480 — (30.7100, -81.5600) ---
# New places found at this point: 60
#
# --- Grid Point 292/3480 — (30.7100, -81.4800) ---
# New places found at this point: 0
#
# --- Grid Point 293/3480 — (30.7100, -81.4000) ---
# New places found at this point: 0
#
# --- Grid Point 294/3480 — (30.7100, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 295/3480 — (30.7100, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 296/3480 — (30.7100, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 297/3480 — (30.7100, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 298/3480 — (30.7100, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 299/3480 — (30.7100, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 300/3480 — (30.7100, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 300 grid points...
# Progress saved: 2647 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 301/3480 — (30.7900, -85.5600) ---
# New places found at this point: 60
#
# --- Grid Point 302/3480 — (30.7900, -85.4800) ---
# New places found at this point: 4
#
# --- Grid Point 303/3480 — (30.7900, -85.4000) ---
# New places found at this point: 8
#
# --- Grid Point 304/3480 — (30.7900, -85.3200) ---
# New places found at this point: 7
#
# --- Grid Point 305/3480 — (30.7900, -85.2400) ---
# New places found at this point: 60
#
# --- Grid Point 306/3480 — (30.7900, -85.1600) ---
# New places found at this point: 21
#
# --- Grid Point 307/3480 — (30.7900, -85.0800) ---
# New places found at this point: 0
#
# --- Grid Point 308/3480 — (30.7900, -85.0000) ---
# New places found at this point: 3
#
# --- Grid Point 309/3480 — (30.7900, -84.9200) ---
# New places found at this point: 8
#
# --- Grid Point 310/3480 — (30.7900, -84.8400) ---
# New places found at this point: 12
#
# 💾 [Checkpoint] Saving progress at 310 grid points...
# Progress saved: 2830 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 311/3480 — (30.7900, -84.7600) ---
# New places found at this point: 1
#
# --- Grid Point 312/3480 — (30.7900, -84.6800) ---
# New places found at this point: 1
#
# --- Grid Point 313/3480 — (30.7900, -84.6000) ---
# New places found at this point: 2
#
# --- Grid Point 314/3480 — (30.7900, -84.5200) ---
# New places found at this point: 2
#
# --- Grid Point 315/3480 — (30.7900, -84.4400) ---
# New places found at this point: 0
#
# --- Grid Point 316/3480 — (30.7900, -84.3600) ---
# New places found at this point: 1
#
# --- Grid Point 317/3480 — (30.7900, -84.2800) ---
# New places found at this point: 6
#
# --- Grid Point 318/3480 — (30.7900, -84.2000) ---
# New places found at this point: 6
#
# --- Grid Point 319/3480 — (30.7900, -84.1200) ---
# New places found at this point: 1
#
# --- Grid Point 320/3480 — (30.7900, -84.0400) ---
# New places found at this point: 5
#
# 💾 [Checkpoint] Saving progress at 320 grid points...
# Progress saved: 2855 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 321/3480 — (30.7900, -83.9600) ---
# New places found at this point: 1
#
# --- Grid Point 322/3480 — (30.7900, -83.8800) ---
# New places found at this point: 4
#
# --- Grid Point 323/3480 — (30.7900, -83.8000) ---
# New places found at this point: 60
#
# --- Grid Point 324/3480 — (30.7900, -83.7200) ---
# New places found at this point: 3
#
# --- Grid Point 325/3480 — (30.7900, -83.6400) ---
# New places found at this point: 6
#
# --- Grid Point 326/3480 — (30.7900, -83.5600) ---
# New places found at this point: 60
#
# --- Grid Point 327/3480 — (30.7900, -83.4800) ---
# New places found at this point: 4
#
# --- Grid Point 328/3480 — (30.7900, -83.4000) ---
# New places found at this point: 4
#
# --- Grid Point 329/3480 — (30.7900, -83.3200) ---
# New places found at this point: 6
#
# --- Grid Point 330/3480 — (30.7900, -83.2400) ---
# New places found at this point: 49
#
# 💾 [Checkpoint] Saving progress at 330 grid points...
# Progress saved: 3052 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 331/3480 — (30.7900, -83.1600) ---
# New places found at this point: 12
#
# --- Grid Point 332/3480 — (30.7900, -83.0800) ---
# New places found at this point: 0
#
# --- Grid Point 333/3480 — (30.7900, -83.0000) ---
# New places found at this point: 0
#
# --- Grid Point 334/3480 — (30.7900, -82.9200) ---
# New places found at this point: 0
#
# --- Grid Point 335/3480 — (30.7900, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 336/3480 — (30.7900, -82.7600) ---
# New places found at this point: 0
#
# --- Grid Point 337/3480 — (30.7900, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 338/3480 — (30.7900, -82.6000) ---
# New places found at this point: 0
#
# --- Grid Point 339/3480 — (30.7900, -82.5200) ---
# New places found at this point: 1
#
# --- Grid Point 340/3480 — (30.7900, -82.4400) ---
# New places found at this point: 2
#
# 💾 [Checkpoint] Saving progress at 340 grid points...
# Progress saved: 3067 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 341/3480 — (30.7900, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 342/3480 — (30.7900, -82.2800) ---
# New places found at this point: 0
#
# --- Grid Point 343/3480 — (30.7900, -82.2000) ---
# New places found at this point: 0
#
# --- Grid Point 344/3480 — (30.7900, -82.1200) ---
# New places found at this point: 1
#
# --- Grid Point 345/3480 — (30.7900, -82.0400) ---
# New places found at this point: 8
#
# --- Grid Point 346/3480 — (30.7900, -81.9600) ---
# New places found at this point: 7
#
# --- Grid Point 347/3480 — (30.7900, -81.8800) ---
# New places found at this point: 0
#
# --- Grid Point 348/3480 — (30.7900, -81.8000) ---
# New places found at this point: 13
#
# --- Grid Point 349/3480 — (30.7900, -81.7200) ---
# New places found at this point: 26
#
# --- Grid Point 350/3480 — (30.7900, -81.6400) ---
# New places found at this point: 59
#
# 💾 [Checkpoint] Saving progress at 350 grid points...
# Progress saved: 3181 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 351/3480 — (30.7900, -81.5600) ---
# New places found at this point: 59
#
# --- Grid Point 352/3480 — (30.7900, -81.4800) ---
# New places found at this point: 2
#
# --- Grid Point 353/3480 — (30.7900, -81.4000) ---
# New places found at this point: 0
#
# --- Grid Point 354/3480 — (30.7900, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 355/3480 — (30.7900, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 356/3480 — (30.7900, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 357/3480 — (30.7900, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 358/3480 — (30.7900, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 359/3480 — (30.7900, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 360/3480 — (30.7900, -80.8400) ---
# Error fetching train_station at 30.7900,-80.8400: 500 Server Error: Internal Server Error for url: https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=30.789999999999992%2C-80.84000000000009&radius=2000&type=train_station&key=AIzaSyC5sawi_f7fI6X47XaKwUBFNvFRJq3VDJc
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 360 grid points...
# Progress saved: 3242 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 361/3480 — (30.8700, -85.5600) ---
# New places found at this point: 3
#
# --- Grid Point 362/3480 — (30.8700, -85.4800) ---
# New places found at this point: 9
#
# --- Grid Point 363/3480 — (30.8700, -85.4000) ---
# New places found at this point: 1
#
# --- Grid Point 364/3480 — (30.8700, -85.3200) ---
# New places found at this point: 0
#
# --- Grid Point 365/3480 — (30.8700, -85.2400) ---
# New places found at this point: 3
#
# --- Grid Point 366/3480 — (30.8700, -85.1600) ---
# New places found at this point: 28
#
# --- Grid Point 367/3480 — (30.8700, -85.0800) ---
# New places found at this point: 8
#
# --- Grid Point 368/3480 — (30.8700, -85.0000) ---
# New places found at this point: 1
#
# --- Grid Point 369/3480 — (30.8700, -84.9200) ---
# New places found at this point: 0
#
# --- Grid Point 370/3480 — (30.8700, -84.8400) ---
# New places found at this point: 1
#
# 💾 [Checkpoint] Saving progress at 370 grid points...
# Progress saved: 3296 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 371/3480 — (30.8700, -84.7600) ---
# New places found at this point: 9
#
# --- Grid Point 372/3480 — (30.8700, -84.6800) ---
# New places found at this point: 6
#
# --- Grid Point 373/3480 — (30.8700, -84.6000) ---
# New places found at this point: 17
#
# --- Grid Point 374/3480 — (30.8700, -84.5200) ---
# New places found at this point: 7
#
# --- Grid Point 375/3480 — (30.8700, -84.4400) ---
# New places found at this point: 29
#
# --- Grid Point 376/3480 — (30.8700, -84.3600) ---
# New places found at this point: 4
#
# --- Grid Point 377/3480 — (30.8700, -84.2800) ---
# New places found at this point: 15
#
# --- Grid Point 378/3480 — (30.8700, -84.2000) ---
# New places found at this point: 60
#
# --- Grid Point 379/3480 — (30.8700, -84.1200) ---
# New places found at this point: 23
#
# --- Grid Point 380/3480 — (30.8700, -84.0400) ---
# New places found at this point: 3
#
# 💾 [Checkpoint] Saving progress at 380 grid points...
# Progress saved: 3469 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 381/3480 — (30.8700, -83.9600) ---
# New places found at this point: 60
#
# --- Grid Point 382/3480 — (30.8700, -83.8800) ---
# New places found at this point: 3
#
# --- Grid Point 383/3480 — (30.8700, -83.8000) ---
# New places found at this point: 5
#
# --- Grid Point 384/3480 — (30.8700, -83.7200) ---
# New places found at this point: 3
#
# --- Grid Point 385/3480 — (30.8700, -83.6400) ---
# New places found at this point: 0
#
# --- Grid Point 386/3480 — (30.8700, -83.5600) ---
# New places found at this point: 2
#
# --- Grid Point 387/3480 — (30.8700, -83.4800) ---
# New places found at this point: 1
#
# --- Grid Point 388/3480 — (30.8700, -83.4000) ---
# New places found at this point: 23
#
# --- Grid Point 389/3480 — (30.8700, -83.3200) ---
# New places found at this point: 59
#
# --- Grid Point 390/3480 — (30.8700, -83.2400) ---
# New places found at this point: 59
#
# 💾 [Checkpoint] Saving progress at 390 grid points...
# Progress saved: 3684 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 391/3480 — (30.8700, -83.1600) ---
# New places found at this point: 0
#
# --- Grid Point 392/3480 — (30.8700, -83.0800) ---
# New places found at this point: 0
#
# --- Grid Point 393/3480 — (30.8700, -83.0000) ---
# New places found at this point: 1
#
# --- Grid Point 394/3480 — (30.8700, -82.9200) ---
# New places found at this point: 0
#
# --- Grid Point 395/3480 — (30.8700, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 396/3480 — (30.8700, -82.7600) ---
# New places found at this point: 0
#
# --- Grid Point 397/3480 — (30.8700, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 398/3480 — (30.8700, -82.6000) ---
# New places found at this point: 0
#
# --- Grid Point 399/3480 — (30.8700, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 400/3480 — (30.8700, -82.4400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 400 grid points...
# Progress saved: 3685 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 401/3480 — (30.8700, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 402/3480 — (30.8700, -82.2800) ---
# New places found at this point: 0
#
# --- Grid Point 403/3480 — (30.8700, -82.2000) ---
# New places found at this point: 0
#
# --- Grid Point 404/3480 — (30.8700, -82.1200) ---
# New places found at this point: 0
#
# --- Grid Point 405/3480 — (30.8700, -82.0400) ---
# New places found at this point: 3
#
# --- Grid Point 406/3480 — (30.8700, -81.9600) ---
# New places found at this point: 2
#
# --- Grid Point 407/3480 — (30.8700, -81.8800) ---
# New places found at this point: 0
#
# --- Grid Point 408/3480 — (30.8700, -81.8000) ---
# New places found at this point: 3
#
# --- Grid Point 409/3480 — (30.8700, -81.7200) ---
# New places found at this point: 2
#
# --- Grid Point 410/3480 — (30.8700, -81.6400) ---
# New places found at this point: 11
#
# 💾 [Checkpoint] Saving progress at 410 grid points...
# Progress saved: 3706 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 411/3480 — (30.8700, -81.5600) ---
# New places found at this point: 0
#
# --- Grid Point 412/3480 — (30.8700, -81.4800) ---
# New places found at this point: 0
#
# --- Grid Point 413/3480 — (30.8700, -81.4000) ---
# New places found at this point: 0
#
# --- Grid Point 414/3480 — (30.8700, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 415/3480 — (30.8700, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 416/3480 — (30.8700, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 417/3480 — (30.8700, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 418/3480 — (30.8700, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 419/3480 — (30.8700, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 420/3480 — (30.8700, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 420 grid points...
# Progress saved: 3706 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 421/3480 — (30.9500, -85.5600) ---
# New places found at this point: 5
#
# --- Grid Point 422/3480 — (30.9500, -85.4800) ---
# New places found at this point: 14
#
# --- Grid Point 423/3480 — (30.9500, -85.4000) ---
# New places found at this point: 36
#
# --- Grid Point 424/3480 — (30.9500, -85.3200) ---
# New places found at this point: 1
#
# --- Grid Point 425/3480 — (30.9500, -85.2400) ---
# New places found at this point: 2
#
# --- Grid Point 426/3480 — (30.9500, -85.1600) ---
# New places found at this point: 52
#
# --- Grid Point 427/3480 — (30.9500, -85.0800) ---
# New places found at this point: 1
#
# --- Grid Point 428/3480 — (30.9500, -85.0000) ---
# New places found at this point: 0
#
# --- Grid Point 429/3480 — (30.9500, -84.9200) ---
# New places found at this point: 1
#
# --- Grid Point 430/3480 — (30.9500, -84.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 430 grid points...
# Progress saved: 3818 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 431/3480 — (30.9500, -84.7600) ---
# New places found at this point: 1
#
# --- Grid Point 432/3480 — (30.9500, -84.6800) ---
# New places found at this point: 7
#
# --- Grid Point 433/3480 — (30.9500, -84.6000) ---
# New places found at this point: 13
#
# --- Grid Point 434/3480 — (30.9500, -84.5200) ---
# New places found at this point: 12
#
# --- Grid Point 435/3480 — (30.9500, -84.4400) ---
# New places found at this point: 3
#
# --- Grid Point 436/3480 — (30.9500, -84.3600) ---
# New places found at this point: 1
#
# --- Grid Point 437/3480 — (30.9500, -84.2800) ---
# New places found at this point: 2
#
# --- Grid Point 438/3480 — (30.9500, -84.2000) ---
# New places found at this point: 9
#
# --- Grid Point 439/3480 — (30.9500, -84.1200) ---
# New places found at this point: 1
#
# --- Grid Point 440/3480 — (30.9500, -84.0400) ---
# New places found at this point: 4
#
# 💾 [Checkpoint] Saving progress at 440 grid points...
# Progress saved: 3871 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 441/3480 — (30.9500, -83.9600) ---
# New places found at this point: 5
#
# --- Grid Point 442/3480 — (30.9500, -83.8800) ---
# New places found at this point: 5
#
# --- Grid Point 443/3480 — (30.9500, -83.8000) ---
# New places found at this point: 3
#
# --- Grid Point 444/3480 — (30.9500, -83.7200) ---
# New places found at this point: 14
#
# --- Grid Point 445/3480 — (30.9500, -83.6400) ---
# New places found at this point: 1
#
# --- Grid Point 446/3480 — (30.9500, -83.5600) ---
# New places found at this point: 0
#
# --- Grid Point 447/3480 — (30.9500, -83.4800) ---
# New places found at this point: 21
#
# --- Grid Point 448/3480 — (30.9500, -83.4000) ---
# New places found at this point: 6
#
# --- Grid Point 449/3480 — (30.9500, -83.3200) ---
# New places found at this point: 8
#
# --- Grid Point 450/3480 — (30.9500, -83.2400) ---
# New places found at this point: 48
#
# 💾 [Checkpoint] Saving progress at 450 grid points...
# Progress saved: 3982 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 451/3480 — (30.9500, -83.1600) ---
# New places found at this point: 1
#
# --- Grid Point 452/3480 — (30.9500, -83.0800) ---
# New places found at this point: 9
#
# --- Grid Point 453/3480 — (30.9500, -83.0000) ---
# New places found at this point: 9
#
# --- Grid Point 454/3480 — (30.9500, -82.9200) ---
# New places found at this point: 0
#
# --- Grid Point 455/3480 — (30.9500, -82.8400) ---
# New places found at this point: 0
#
# --- Grid Point 456/3480 — (30.9500, -82.7600) ---
# New places found at this point: 0
#
# --- Grid Point 457/3480 — (30.9500, -82.6800) ---
# New places found at this point: 0
#
# --- Grid Point 458/3480 — (30.9500, -82.6000) ---
# New places found at this point: 1
#
# --- Grid Point 459/3480 — (30.9500, -82.5200) ---
# New places found at this point: 0
#
# --- Grid Point 460/3480 — (30.9500, -82.4400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 460 grid points...
# Progress saved: 4002 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 461/3480 — (30.9500, -82.3600) ---
# New places found at this point: 0
#
# --- Grid Point 462/3480 — (30.9500, -82.2800) ---
# New places found at this point: 1
#
# --- Grid Point 463/3480 — (30.9500, -82.2000) ---
# New places found at this point: 0
#
# --- Grid Point 464/3480 — (30.9500, -82.1200) ---
# New places found at this point: 4
#
# --- Grid Point 465/3480 — (30.9500, -82.0400) ---
# New places found at this point: 0
#
# --- Grid Point 466/3480 — (30.9500, -81.9600) ---
# New places found at this point: 1
#
# --- Grid Point 467/3480 — (30.9500, -81.8800) ---
# New places found at this point: 0
#
# --- Grid Point 468/3480 — (30.9500, -81.8000) ---
# New places found at this point: 1
#
# --- Grid Point 469/3480 — (30.9500, -81.7200) ---
# New places found at this point: 60
#
# --- Grid Point 470/3480 — (30.9500, -81.6400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 470 grid points...
# Progress saved: 4069 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 471/3480 — (30.9500, -81.5600) ---
# New places found at this point: 0
#
# --- Grid Point 472/3480 — (30.9500, -81.4800) ---
# New places found at this point: 0
#
# --- Grid Point 473/3480 — (30.9500, -81.4000) ---
# New places found at this point: 1
#
# --- Grid Point 474/3480 — (30.9500, -81.3200) ---
# New places found at this point: 0
#
# --- Grid Point 475/3480 — (30.9500, -81.2400) ---
# New places found at this point: 0
#
# --- Grid Point 476/3480 — (30.9500, -81.1600) ---
# New places found at this point: 0
#
# --- Grid Point 477/3480 — (30.9500, -81.0800) ---
# New places found at this point: 0
#
# --- Grid Point 478/3480 — (30.9500, -81.0000) ---
# New places found at this point: 0
#
# --- Grid Point 479/3480 — (30.9500, -80.9200) ---
# New places found at this point: 0
#
# --- Grid Point 480/3480 — (30.9500, -80.8400) ---
# New places found at this point: 0
#
# 💾 [Checkpoint] Saving progress at 480 grid points...
# Progress saved: 4070 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# ...
#
# --- Grid Point 3324/3480 — (34.7900, -83.7200) ---
# New places found at this point: 4
#
# --- Grid Point 3325/3480 — (34.7900, -83.6400) ---
# New places found at this point: 1
#
# --- Grid Point 3326/3480 — (34.7900, -83.5600) ---
# New places found at this point: 21
#
# --- Grid Point 3327/3480 — (34.7900, -83.4800) ---
# New places found at this point: 0
#
# --- Grid Point 3328/3480 — (34.7900, -83.4000) ---
# New places found at this point: 42
#
# --- Grid Point 3329/3480 — (34.7900, -83.3200) ---
# New places found at this point: 3
#
# --- Grid Point 3330/3480 — (34.7900, -83.2400) ---
# New places found at this point: 12
#
# 💾 [Checkpoint] Saving progress at 3330 grid points...
# Progress saved: 41903 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3331/3480 — (34.7900, -83.1600) ---
# New places found at this point: 3
#
# --- Grid Point 3332/3480 — (34.7900, -83.0800) ---
# New places found at this point: 14
#
# --- Grid Point 3333/3480 — (34.7900, -83.0000) ---
# New places found at this point: 24
#
# --- Grid Point 3334/3480 — (34.7900, -82.9200) ---
# New places found at this point: 30
#
# --- Grid Point 3335/3480 — (34.7900, -82.8400) ---
# New places found at this point: 14
#
# --- Grid Point 3336/3480 — (34.7900, -82.7600) ---
# New places found at this point: 16
#
# --- Grid Point 3337/3480 — (34.7900, -82.6800) ---
# New places found at this point: 60
#
# --- Grid Point 3338/3480 — (34.7900, -82.6000) ---
# New places found at this point: 60
#
# --- Grid Point 3339/3480 — (34.7900, -82.5200) ---
# New places found at this point: 59
#
# --- Grid Point 3340/3480 — (34.7900, -82.4400) ---
# New places found at this point: 61
#
# 💾 [Checkpoint] Saving progress at 3340 grid points...
# Progress saved: 42244 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3341/3480 — (34.7900, -82.3600) ---
# New places found at this point: 67
#
# --- Grid Point 3342/3480 — (34.7900, -82.2800) ---
# New places found at this point: 60
#
# --- Grid Point 3343/3480 — (34.7900, -82.2000) ---
# New places found at this point: 59
#
# --- Grid Point 3344/3480 — (34.7900, -82.1200) ---
# New places found at this point: 21
#
# --- Grid Point 3345/3480 — (34.7900, -82.0400) ---
# New places found at this point: 10
#
# --- Grid Point 3346/3480 — (34.7900, -81.9600) ---
# New places found at this point: 7
#
# --- Grid Point 3347/3480 — (34.7900, -81.8800) ---
# New places found at this point: 12
#
# --- Grid Point 3348/3480 — (34.7900, -81.8000) ---
# New places found at this point: 3
#
# --- Grid Point 3349/3480 — (34.7900, -81.7200) ---
# New places found at this point: 1
#
# --- Grid Point 3350/3480 — (34.7900, -81.6400) ---
# New places found at this point: 16
#
# 💾 [Checkpoint] Saving progress at 3350 grid points...
# Progress saved: 42500 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3351/3480 — (34.7900, -81.5600) ---
# New places found at this point: 3
#
# --- Grid Point 3352/3480 — (34.7900, -81.4800) ---
# New places found at this point: 34
#
# --- Grid Point 3353/3480 — (34.7900, -81.4000) ---
# New places found at this point: 0
#
# --- Grid Point 3354/3480 — (34.7900, -81.3200) ---
# New places found at this point: 1
#
# --- Grid Point 3355/3480 — (34.7900, -81.2400) ---
# New places found at this point: 18
#
# --- Grid Point 3356/3480 — (34.7900, -81.1600) ---
# New places found at this point: 1
#
# --- Grid Point 3357/3480 — (34.7900, -81.0800) ---
# New places found at this point: 6
#
# --- Grid Point 3358/3480 — (34.7900, -81.0000) ---
# New places found at this point: 24
#
# --- Grid Point 3359/3480 — (34.7900, -80.9200) ---
# New places found at this point: 9
#
# --- Grid Point 3360/3480 — (34.7900, -80.8400) ---
# New places found at this point: 9
#
# 💾 [Checkpoint] Saving progress at 3360 grid points...
# Progress saved: 42605 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3361/3480 — (34.8700, -85.5600) ---
# New places found at this point: 36
#
# --- Grid Point 3362/3480 — (34.8700, -85.4800) ---
# New places found at this point: 19
#
# --- Grid Point 3363/3480 — (34.8700, -85.4000) ---
# New places found at this point: 10
#
# --- Grid Point 3364/3480 — (34.8700, -85.3200) ---
# New places found at this point: 27
#
# --- Grid Point 3365/3480 — (34.8700, -85.2400) ---
# New places found at this point: 26
#
# --- Grid Point 3366/3480 — (34.8700, -85.1600) ---
# New places found at this point: 34
#
# --- Grid Point 3367/3480 — (34.8700, -85.0800) ---
# New places found at this point: 21
#
# --- Grid Point 3368/3480 — (34.8700, -85.0000) ---
# New places found at this point: 32
#
# --- Grid Point 3369/3480 — (34.8700, -84.9200) ---
# New places found at this point: 20
#
# --- Grid Point 3370/3480 — (34.8700, -84.8400) ---
# New places found at this point: 4
#
# 💾 [Checkpoint] Saving progress at 3370 grid points...
# Progress saved: 42834 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3371/3480 — (34.8700, -84.7600) ---
# New places found at this point: 36
#
# --- Grid Point 3372/3480 — (34.8700, -84.6800) ---
# New places found at this point: 0
#
# --- Grid Point 3373/3480 — (34.8700, -84.6000) ---
# New places found at this point: 1
#
# --- Grid Point 3374/3480 — (34.8700, -84.5200) ---
# New places found at this point: 5
#
# --- Grid Point 3375/3480 — (34.8700, -84.4400) ---
# New places found at this point: 27
#
# --- Grid Point 3376/3480 — (34.8700, -84.3600) ---
# New places found at this point: 38
#
# --- Grid Point 3377/3480 — (34.8700, -84.2800) ---
# New places found at this point: 60
#
# --- Grid Point 3378/3480 — (34.8700, -84.2000) ---
# New places found at this point: 17
#
# --- Grid Point 3379/3480 — (34.8700, -84.1200) ---
# New places found at this point: 29
#
# --- Grid Point 3380/3480 — (34.8700, -84.0400) ---
# New places found at this point: 18
#
# 💾 [Checkpoint] Saving progress at 3380 grid points...
# Progress saved: 43065 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3381/3480 — (34.8700, -83.9600) ---
# New places found at this point: 60
#
# --- Grid Point 3382/3480 — (34.8700, -83.8800) ---
# New places found at this point: 10
#
# --- Grid Point 3383/3480 — (34.8700, -83.8000) ---
# New places found at this point: 6
#
# --- Grid Point 3384/3480 — (34.8700, -83.7200) ---
# New places found at this point: 13
#
# --- Grid Point 3385/3480 — (34.8700, -83.6400) ---
# New places found at this point: 3
#
# --- Grid Point 3386/3480 — (34.8700, -83.5600) ---
# New places found at this point: 7
#
# --- Grid Point 3387/3480 — (34.8700, -83.4800) ---
# New places found at this point: 5
#
# --- Grid Point 3388/3480 — (34.8700, -83.4000) ---
# New places found at this point: 60
#
# --- Grid Point 3389/3480 — (34.8700, -83.3200) ---
# New places found at this point: 3
#
# --- Grid Point 3390/3480 — (34.8700, -83.2400) ---
# New places found at this point: 6
#
# 💾 [Checkpoint] Saving progress at 3390 grid points...
# Progress saved: 43238 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3391/3480 — (34.8700, -83.1600) ---
# New places found at this point: 15
#
# --- Grid Point 3392/3480 — (34.8700, -83.0800) ---
# New places found at this point: 4
#
# --- Grid Point 3393/3480 — (34.8700, -83.0000) ---
# New places found at this point: 19
#
# --- Grid Point 3394/3480 — (34.8700, -82.9200) ---
# New places found at this point: 6
#
# --- Grid Point 3395/3480 — (34.8700, -82.8400) ---
# New places found at this point: 11
#
# --- Grid Point 3396/3480 — (34.8700, -82.7600) ---
# New places found at this point: 30
#
# --- Grid Point 3397/3480 — (34.8700, -82.6800) ---
# New places found at this point: 60
#
# --- Grid Point 3398/3480 — (34.8700, -82.6000) ---
# New places found at this point: 34
#
# --- Grid Point 3399/3480 — (34.8700, -82.5200) ---
# New places found at this point: 31
#
# --- Grid Point 3400/3480 — (34.8700, -82.4400) ---
# New places found at this point: 71
#
# 💾 [Checkpoint] Saving progress at 3400 grid points...
# Progress saved: 43519 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3401/3480 — (34.8700, -82.3600) ---
# New places found at this point: 92
#
# --- Grid Point 3402/3480 — (34.8700, -82.2800) ---
# New places found at this point: 59
#
# --- Grid Point 3403/3480 — (34.8700, -82.2000) ---
# New places found at this point: 60
#
# --- Grid Point 3404/3480 — (34.8700, -82.1200) ---
# New places found at this point: 60
#
# --- Grid Point 3405/3480 — (34.8700, -82.0400) ---
# New places found at this point: 60
#
# --- Grid Point 3406/3480 — (34.8700, -81.9600) ---
# New places found at this point: 60
#
# --- Grid Point 3407/3480 — (34.8700, -81.8800) ---
# New places found at this point: 11
#
# --- Grid Point 3408/3480 — (34.8700, -81.8000) ---
# New places found at this point: 2
#
# --- Grid Point 3409/3480 — (34.8700, -81.7200) ---
# New places found at this point: 7
#
# --- Grid Point 3410/3480 — (34.8700, -81.6400) ---
# New places found at this point: 3
#
# 💾 [Checkpoint] Saving progress at 3410 grid points...
# Progress saved: 43933 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3411/3480 — (34.8700, -81.5600) ---
# New places found at this point: 2
#
# --- Grid Point 3412/3480 — (34.8700, -81.4800) ---
# New places found at this point: 0
#
# --- Grid Point 3413/3480 — (34.8700, -81.4000) ---
# New places found at this point: 4
#
# --- Grid Point 3414/3480 — (34.8700, -81.3200) ---
# New places found at this point: 5
#
# --- Grid Point 3415/3480 — (34.8700, -81.2400) ---
# New places found at this point: 29
#
# --- Grid Point 3416/3480 — (34.8700, -81.1600) ---
# New places found at this point: 9
#
# --- Grid Point 3417/3480 — (34.8700, -81.0800) ---
# New places found at this point: 15
#
# --- Grid Point 3418/3480 — (34.8700, -81.0000) ---
# New places found at this point: 47
#
# --- Grid Point 3419/3480 — (34.8700, -80.9200) ---
# New places found at this point: 29
#
# --- Grid Point 3420/3480 — (34.8700, -80.8400) ---
# New places found at this point: 25
#
# 💾 [Checkpoint] Saving progress at 3420 grid points...
# Progress saved: 44098 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3421/3480 — (34.9500, -85.5600) ---
# New places found at this point: 2
#
# --- Grid Point 3422/3480 — (34.9500, -85.4800) ---
# New places found at this point: 10
#
# --- Grid Point 3423/3480 — (34.9500, -85.4000) ---
# New places found at this point: 19
#
# --- Grid Point 3424/3480 — (34.9500, -85.3200) ---
# New places found at this point: 60
#
# --- Grid Point 3425/3480 — (34.9500, -85.2400) ---
# New places found at this point: 60
#
# --- Grid Point 3426/3480 — (34.9500, -85.1600) ---
# New places found at this point: 59
#
# --- Grid Point 3427/3480 — (34.9500, -85.0800) ---
# New places found at this point: 7
#
# --- Grid Point 3428/3480 — (34.9500, -85.0000) ---
# New places found at this point: 4
#
# --- Grid Point 3429/3480 — (34.9500, -84.9200) ---
# New places found at this point: 5
#
# --- Grid Point 3430/3480 — (34.9500, -84.8400) ---
# New places found at this point: 7
#
# 💾 [Checkpoint] Saving progress at 3430 grid points...
# Progress saved: 44331 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3431/3480 — (34.9500, -84.7600) ---
# New places found at this point: 15
#
# --- Grid Point 3432/3480 — (34.9500, -84.6800) ---
# New places found at this point: 2
#
# --- Grid Point 3433/3480 — (34.9500, -84.6000) ---
# New places found at this point: 1
#
# --- Grid Point 3434/3480 — (34.9500, -84.5200) ---
# New places found at this point: 0
#
# --- Grid Point 3435/3480 — (34.9500, -84.4400) ---
# New places found at this point: 30
#
# --- Grid Point 3436/3480 — (34.9500, -84.3600) ---
# New places found at this point: 60
#
# --- Grid Point 3437/3480 — (34.9500, -84.2800) ---
# New places found at this point: 20
#
# --- Grid Point 3438/3480 — (34.9500, -84.2000) ---
# New places found at this point: 17
#
# --- Grid Point 3439/3480 — (34.9500, -84.1200) ---
# New places found at this point: 28
#
# --- Grid Point 3440/3480 — (34.9500, -84.0400) ---
# New places found at this point: 20
#
# 💾 [Checkpoint] Saving progress at 3440 grid points...
# Progress saved: 44524 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3441/3480 — (34.9500, -83.9600) ---
# New places found at this point: 3
#
# --- Grid Point 3442/3480 — (34.9500, -83.8800) ---
# New places found at this point: 14
#
# --- Grid Point 3443/3480 — (34.9500, -83.8000) ---
# New places found at this point: 45
#
# --- Grid Point 3444/3480 — (34.9500, -83.7200) ---
# New places found at this point: 13
#
# --- Grid Point 3445/3480 — (34.9500, -83.6400) ---
# New places found at this point: 10
#
# --- Grid Point 3446/3480 — (34.9500, -83.5600) ---
# New places found at this point: 4
#
# --- Grid Point 3447/3480 — (34.9500, -83.4800) ---
# New places found at this point: 4
#
# --- Grid Point 3448/3480 — (34.9500, -83.4000) ---
# New places found at this point: 60
#
# --- Grid Point 3449/3480 — (34.9500, -83.3200) ---
# New places found at this point: 5
#
# --- Grid Point 3450/3480 — (34.9500, -83.2400) ---
# New places found at this point: 4
#
# 💾 [Checkpoint] Saving progress at 3450 grid points...
# Progress saved: 44686 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3451/3480 — (34.9500, -83.1600) ---
# New places found at this point: 0
#
# --- Grid Point 3452/3480 — (34.9500, -83.0800) ---
# New places found at this point: 3
#
# --- Grid Point 3453/3480 — (34.9500, -83.0000) ---
# New places found at this point: 1
#
# --- Grid Point 3454/3480 — (34.9500, -82.9200) ---
# New places found at this point: 16
#
# --- Grid Point 3455/3480 — (34.9500, -82.8400) ---
# New places found at this point: 9
#
# --- Grid Point 3456/3480 — (34.9500, -82.7600) ---
# New places found at this point: 9
#
# --- Grid Point 3457/3480 — (34.9500, -82.6800) ---
# New places found at this point: 16
#
# --- Grid Point 3458/3480 — (34.9500, -82.6000) ---
# New places found at this point: 7
#
# --- Grid Point 3459/3480 — (34.9500, -82.5200) ---
# New places found at this point: 18
#
# --- Grid Point 3460/3480 — (34.9500, -82.4400) ---
# New places found at this point: 60
#
# 💾 [Checkpoint] Saving progress at 3460 grid points...
# Progress saved: 44825 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3461/3480 — (34.9500, -82.3600) ---
# New places found at this point: 48
#
# --- Grid Point 3462/3480 — (34.9500, -82.2800) ---
# New places found at this point: 58
#
# --- Grid Point 3463/3480 — (34.9500, -82.2000) ---
# New places found at this point: 59
#
# --- Grid Point 3464/3480 — (34.9500, -82.1200) ---
# New places found at this point: 60
#
# --- Grid Point 3465/3480 — (34.9500, -82.0400) ---
# New places found at this point: 59
#
# --- Grid Point 3466/3480 — (34.9500, -81.9600) ---
# New places found at this point: 68
#
# --- Grid Point 3467/3480 — (34.9500, -81.8800) ---
# New places found at this point: 59
#
# --- Grid Point 3468/3480 — (34.9500, -81.8000) ---
# New places found at this point: 10
#
# --- Grid Point 3469/3480 — (34.9500, -81.7200) ---
# New places found at this point: 8
#
# --- Grid Point 3470/3480 — (34.9500, -81.6400) ---
# New places found at this point: 3
#
# 💾 [Checkpoint] Saving progress at 3470 grid points...
# Progress saved: 45257 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# --- Grid Point 3471/3480 — (34.9500, -81.5600) ---
# New places found at this point: 2
#
# --- Grid Point 3472/3480 — (34.9500, -81.4800) ---
# New places found at this point: 4
#
# --- Grid Point 3473/3480 — (34.9500, -81.4000) ---
# New places found at this point: 5
#
# --- Grid Point 3474/3480 — (34.9500, -81.3200) ---
# New places found at this point: 25
#
# --- Grid Point 3475/3480 — (34.9500, -81.2400) ---
# New places found at this point: 14
#
# --- Grid Point 3476/3480 — (34.9500, -81.1600) ---
# New places found at this point: 21
#
# --- Grid Point 3477/3480 — (34.9500, -81.0800) ---
# New places found at this point: 61
#
# --- Grid Point 3478/3480 — (34.9500, -81.0000) ---
# New places found at this point: 89
#
# --- Grid Point 3479/3480 — (34.9500, -80.9200) ---
# New places found at this point: 16
#
# --- Grid Point 3480/3480 — (34.9500, -80.8400) ---
# New places found at this point: 60
#
# 💾 [Checkpoint] Saving progress at 3480 grid points...
# Progress saved: 45554 places → georgia_transit_locations_with_hub_20250421_0949.csv
#
# inished all grid points. Total unique places found: 45554
# Saving final results...
# Progress saved: 45554 places → georgia_transit_locations_with_hub_20250421_0949.csv
# 🎉 Done.

# %%
# Data Quality Check 

import pandas as pd

df = pd.DataFrame(all_places_data) 

duplicates = df[df.duplicated()]
print("🔁 Duplicated Rows:\n", duplicates)

missing_rows = df[df.isnull().any(axis=1)]
print("\n❓ Rows with Missing Values:\n", missing_rows)
# Out:
# 🔁 Duplicated Rows:
#  Empty DataFrame
# Columns: [place_id, name, latitude, longitude, types, vicinity, is_potential_hub, source_type]
# Index: []
#
# ❓ Rows with Missing Values:
#  Empty DataFrame
# Columns: [place_id, name, latitude, longitude, types, vicinity, is_potential_hub, source_type]
# Index: []
