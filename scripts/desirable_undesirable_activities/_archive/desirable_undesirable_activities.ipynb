# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from geopy.distance import geodesic
import requests

# %%
import requests
import time

API_KEY = ""
BASE_URL = "https://maps.googleapis.com/maps/api/place/textsearch/json"
QUERY = "Sam's Club in Georgia"

all_places = []
params = {
    "query": QUERY,
    "key": API_KEY
}

while True:
    response = requests.get(BASE_URL, params=params)
    data = response.json()

    for place in data.get("results", []):
        result = {
            "name": place.get("name"),
            "place_id": place.get("place_id"),
            "vicinity": place.get("formatted_address"),  # can also try "vicinity"
            "business_status": place.get("business_status"),
            "lat": place["geometry"]["location"]["lat"],
            "lng": place["geometry"]["location"]["lng"]
        }
        all_places.append(result)
        print(result)  # or write to CSV

    # Check if there’s another page of results
    if "next_page_token" in data:
        time.sleep(2)  # Wait for token to activate
        params = {
            "pagetoken": data["next_page_token"],
            "key": API_KEY
        }
    else:
        break
# Out:
# {'name': "Sam's Club", 'place_id': 'ChIJd5At4SoG9YgRWsEgCXXnXFU', 'vicinity': '2901 Clairmont Rd, Atlanta, GA 30329, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8424575, 'lng': -84.3118834}
# {'name': "Sam's Club", 'place_id': 'ChIJ2QOpHB6m9YgRKFXJQmQOI2Q', 'vicinity': '1940 Mountain Industrial Blvd, Tucker, GA 30084, United States', 'business_status': 'OPERATIONAL', 'lat': 33.83985699999999, 'lng': -84.20201399999999}
# {'name': "Sam's Club", 'place_id': 'ChIJJ2YFbwyj9YgReGPhdrX5hWc', 'vicinity': '3450 Steve Reynolds Blvd, Duluth, GA 30096, United States', 'business_status': 'OPERATIONAL', 'lat': 33.9507879, 'lng': -84.1366702}
# {'name': "Sam's Club", 'place_id': 'ChIJP_QGVGf59IgRJyNmGeNOaok', 'vicinity': '7325 Jonesboro Rd, Morrow, GA 30260, United States', 'business_status': 'OPERATIONAL', 'lat': 33.555735, 'lng': -84.349142}
# {'name': "Sam's Club", 'place_id': 'ChIJ449iuvgT9YgRni03IbzB50M', 'vicinity': '150 Cobb Pkwy SE, Marietta, GA 30060, United States', 'business_status': 'OPERATIONAL', 'lat': 33.9486626, 'lng': -84.5215291}
# {'name': "Sam's Club", 'place_id': 'ChIJg3dYtWW59YgRlhYhaEnUG8c', 'vicinity': '1520 Scenic Hwy N, Snellville, GA 30078, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8894895, 'lng': -84.0078412}
# {'name': "Sam's Club Bakery", 'place_id': 'ChIJq6raK9UH9YgRJSsY4KSiW4E', 'vicinity': '2901 A, 2901 Clairmont Rd, Atlanta, GA 30329, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8428245, 'lng': -84.31152379999999}
# {'name': "Sam's Club", 'place_id': 'ChIJGXQPMt509YgRszN11Yfit_A', 'vicinity': '10600 Davis Dr, Alpharetta, GA 30009, United States', 'business_status': 'OPERATIONAL', 'lat': 34.0430374, 'lng': -84.3151245}
# {'name': "Sam's Club", 'place_id': 'ChIJeevbuTQm9YgR7MpGzkohbOY', 'vicinity': '6995 Concourse Pkwy, Douglasville, GA 30134, United States', 'business_status': 'OPERATIONAL', 'lat': 33.730873, 'lng': -84.756635}
# {'name': "Sam's Club Fulfillment Center", 'place_id': 'ChIJifO6bwAh9YgR5ikmRGFV0hM', 'vicinity': '1000 Douglas Hl Rd, Lithia Springs, GA 30122, United States', 'business_status': 'OPERATIONAL', 'lat': 33.762651, 'lng': -84.610136}
# {'name': "Sam's Club", 'place_id': 'ChIJSfd5n4Vr9YgRaAd5yWv8b1k', 'vicinity': '9464 Main St, Woodstock, GA 30188, United States', 'business_status': 'OPERATIONAL', 'lat': 34.088833, 'lng': -84.52090799999999}
# {'name': "Sam's Club", 'place_id': 'ChIJgQlIUcdZ9IgRaFhzP3v3b1o', 'vicinity': '1765 Jonesboro Rd, McDonough, GA 30253, United States', 'business_status': 'OPERATIONAL', 'lat': 33.4605556, 'lng': -84.21249999999999}
# {'name': "Sam's Club", 'place_id': 'ChIJoc1o8e3B9IgRLZJSNiG-6sc', 'vicinity': '310 Fischer Rd, Sharpsburg, GA 30277, United States', 'business_status': 'OPERATIONAL', 'lat': 33.3999505, 'lng': -84.6242659}
# {'name': "Sam's Club", 'place_id': 'ChIJ4_WUXOo69YgROu2Jzqb1Hj8', 'vicinity': '4798 Jimmy Lee Smith Pkwy, Hiram, GA 30141, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8869402, 'lng': -84.749426}
# {'name': "Sam's Club", 'place_id': 'ChIJay9CZmeU9YgRIp7Rd6w6i1U', 'vicinity': '3383 Buford Dr, Buford, GA 30519, United States', 'business_status': 'OPERATIONAL', 'lat': 34.0729817, 'lng': -83.98095409999999}
# {'name': "Sam's Club", 'place_id': 'ChIJB7Nto7fz9YgR9h_wePkjxHM', 'vicinity': '3839 Mundy Mill Rd, Oakwood, GA 30566, United States', 'business_status': 'OPERATIONAL', 'lat': 34.2302629, 'lng': -83.87387079999999}
# {'name': "Sam's Club Gas Station", 'place_id': 'ChIJIydZEx6m9YgRMTfdvqewEjo', 'vicinity': '1940 Mountain Industrial Blvd, Tucker, GA 30084, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8383847, 'lng': -84.20293629999999}
# {'name': "Sam's Club", 'place_id': 'ChIJxaEp73Rz9ogRnyofeQpSApM', 'vicinity': '4365 Atlanta Hwy, Athens, GA 30606, United States', 'business_status': 'OPERATIONAL', 'lat': 33.9380328, 'lng': -83.4866029}
# {'name': "Sam's Club Bakery", 'place_id': 'ChIJ-7ljAG6p9YgR63VA4qfcyDw', 'vicinity': '1940 Mountain Industrial Blvd, Tucker, GA 30084, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8384728, 'lng': -84.2028782}
# {'name': "Sam's Club Distribution Center", 'place_id': 'ChIJlXyTttPUiogR-GmHKjPx0K0', 'vicinity': '140 Fleet Dr, Villa Rica, GA 30180, United States', 'business_status': 'OPERATIONAL', 'lat': 33.7457275, 'lng': -84.94540049999999}
# {'name': "Sam's Club", 'place_id': 'ChIJVWJKxgKjiogRm_26kY5naSM', 'vicinity': '2550 Redmond Cir, Rome, GA 30165, United States', 'business_status': 'OPERATIONAL', 'lat': 34.272644, 'lng': -85.2308578}
# {'name': "Sam's Club Bakery", 'place_id': 'ChIJ44lVMd509YgREoJOJscZgwY', 'vicinity': '10600 Davis Dr, Alpharetta, GA 30009, United States', 'business_status': 'OPERATIONAL', 'lat': 34.0427074, 'lng': -84.3151893}
# {'name': "Sam's Club Bakery", 'place_id': 'ChIJZQglaAyj9YgRJULR0DBXgj4', 'vicinity': '3450 Steve Reynolds Blvd, Duluth, GA 30096, United States', 'business_status': 'OPERATIONAL', 'lat': 33.9502798, 'lng': -84.13669110000001}
# {'name': "Sam's Club", 'place_id': 'ChIJ1wV7JM_784gRiOKHKwAP6Cc', 'vicinity': '4701 Log Cabin Dr, Macon, GA 31204, United States', 'business_status': 'OPERATIONAL', 'lat': 32.8152861, 'lng': -83.71177349999999}
# {'name': "Sam's Club Tire & Battery", 'place_id': 'ChIJJ2SmR9UH9YgR9SOWY74qFNs', 'vicinity': '2901 Clairmont Rd, Atlanta, GA 30329, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8426041, 'lng': -84.3112652}
# {'name': "Sam's Club", 'place_id': 'ChIJk0kgLT7W5IgRHTY6rKdvo5Y', 'vicinity': '10100 Canal Rd, Brunswick, GA 31525, United States', 'business_status': 'OPERATIONAL', 'lat': 31.231508, 'lng': -81.49640029999999}
# {'name': "Sam's Club Cafe", 'place_id': 'ChIJPcMD4cQH9YgRIMheW3EOohE', 'vicinity': '2901 Clairmont Rd, Atlanta, GA 30329, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8426041, 'lng': -84.3112652}
# {'name': "Sam's Club Hearing Aid Center", 'place_id': 'ChIJd5At4SoG9YgRGZnszf6yw4Y', 'vicinity': '2901 Clairmont Rd, Atlanta, GA 30329, United States', 'business_status': 'OPERATIONAL', 'lat': 33.8426041, 'lng': -84.3112652}
# {'name': "Sam's Club", 'place_id': 'ChIJJ5YcGLpm7ogRX4sq8C7mTE0', 'vicinity': '450 Norman Dr, Valdosta, GA 31601, United States', 'business_status': 'OPERATIONAL', 'lat': 30.82885539999999, 'lng': -83.32032889999999}
# {'name': "Sam's Club", 'place_id': 'ChIJF7Gyg07LjIgRgI2M5H_vtRI', 'vicinity': '5448 Whittlesey Blvd, Columbus, GA 31909, United States', 'business_status': 'OPERATIONAL', 'lat': 32.5412706, 'lng': -84.9478171}

# %%
BASE_URL = "https://maps.googleapis.com/maps/api/place/textsearch/json"
QUERY = "Sams Clubs in Georgia"

all_places = []
params = {
    "query": QUERY,
    "key": API_KEY
}

while True:
    response = requests.get(BASE_URL, params=params)
    data = response.json()

    for place in data.get("results", []):
        result = {
            "name": place.get("name"),
            "place_id": place.get("place_id"),
            'type': place.get("types"),
            "vicinity": place.get("formatted_address"),
            "business_status": place.get("business_status"),
            "lat": place["geometry"]["location"]["lat"],
            "lng": place["geometry"]["location"]["lng"]
        }
        all_places.append(result)

    # Pagination: check for more pages
    if "next_page_token" in data:
        time.sleep(2)  # wait for token to activate
        params = {
            "pagetoken": data["next_page_token"],
            "key": API_KEY
        }
    else:
        break

# Convert to DataFrame and save
df = pd.DataFrame(all_places)
df.to_csv("sams.csv", index=False)

# %%
API_KEY = ""

def get_place_types(query, latitude, longitude, radius=5000):
    """
    Fetch Google Place types for a specific business query (e.g., Walmart).
    """
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": f"{latitude},{longitude}",
        "radius": radius,
        "keyword": query,
        "key": API_KEY
    }
    
    response = requests.get(url, params=params)
    data = response.json()

    # Print API response for debugging
    print("API Response:", data)

    if data.get("status") != "OK":
        print(f"Error: {data.get('error_message', 'Unknown error')}")
        return []

    if "results" in data:
        for place in data["results"]:
            print(f"Name: {place['name']}")
            print(f"Types: {place['types']}\n")

# Example usage: Find Walmart types in Atlanta

# %%
get_place_types("sams club", 33.84, -84.31)

# 33.7490, -84.3880
# {'location': {'lat': 33.7374337, 'lng': -84.4330913},
# Out:
# API Response: {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 33.8424575, 'lng': -84.3118834}, 'viewport': {'northeast': {'lat': 33.84371252989272, 'lng': -84.31057617010728}, 'southwest': {'lat': 33.84101287010728, 'lng': -84.31327582989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet', 'name': "Sam's Club", 'opening_hours': {'open_now': True}, 'photos': [{'height': 768, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103412413495065523869">Steve PhoenixPerseverance ThrutheSeverest</a>'], 'photo_reference': 'AeeoHcKncUxIXQmqbq5H5WMxQZCxeFe2o_82pQlm4XLDilEpWABQEL1SMf0yIk65qerhJTLV46L_W01MOvYbJOAwPISV0XaRJ5EVyogfRRO0bD2SsIBube_4YqrMQ_Gi_EnNG9RSDxc-NZliuuQdCiKoFHW35dxkyAD3Vz1SHKQfLOdR1HpyksAVvWZCtADxkkOrYZ9kUTXGBNMO4OqUxEp5SsiZgmk6JqzHCgum2iAGKRA89vNLre753DwOirHQ3yO6EX6Qpxr4sXBmzIrVEkjlBNj0cyA5riGTD1QPUE30k3H4secwxU_iPDvlwxqUVzhbprPyIgTGefhZnBhJOqsr1vqc6HU12tE2U97a4hBlVkVc_QBEls59NLQIVcefXimICuoKTtXuo7khdfDDmzNq2rV40qhE7vCqkQ5rKaKeLBW24hXdslDRVAw04VHoZevA6MFjz_KRTYR7AY-jBHVGgFAk20s4UsZF0YgEuy7xDYamlkfEFfWaIf8E-der0eJag8__mjbDFaimudKPjyok7CiZcYS57IyTLLuzL-YmzhvgAQhJdC5peIryeqzcS9bDt1SQyzMPpRU5Og', 'width': 1024}], 'place_id': 'ChIJd5At4SoG9YgRWsEgCXXnXFU', 'plus_code': {'compound_code': 'RMRQ+X6 Atlanta, Georgia', 'global_code': '865QRMRQ+X6'}, 'price_level': 1, 'rating': 4, 'reference': 'ChIJd5At4SoG9YgRWsEgCXXnXFU', 'scope': 'GOOGLE', 'types': ['electronics_store', 'bakery', 'liquor_store', 'food', 'store', 'point_of_interest', 'establishment'], 'user_ratings_total': 1633, 'vicinity': '2901 Clairmont Rd, Atlanta'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 33.841504, 'lng': -84.3118226}, 'viewport': {'northeast': {'lat': 33.84286127989272, 'lng': -84.31043142010728}, 'southwest': {'lat': 33.84016162010727, 'lng': -84.31313107989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/gas_station-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/gas_pinlet', 'name': "Sam's Club Gas Station", 'opening_hours': {'open_now': True}, 'photos': [{'height': 4032, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116476303152263394571">Andrew Wang</a>'], 'photo_reference': 'AeeoHcJd6zkZa4b1qzACjRwnLoyTL1dz7r9JgRWj2LDheqD26XvDwZIfztMsYQyXEs-6rrC203XEJhSQCQyzdCGU9KweSUqKxHDK5jh1JClSVKaRbTg5VtuCyx-sqYOk94MCvvwd-vizM218qNJ-o5oMwsf_JvMACGP9tJ2zhxTJslheCRpOQiKomgaE_AkdSsQNHbZlDDgvH1OozkhoO1k9-SzqYKx5HHhhpnG4XVpddKAps9as3btCNJ_4xzMk-v8fggSlYugQ2prfJF5FwTBBnxfACxT--EIbpadsEa6iaH_co01MKcl_ZudvcSCoilag3w4Da2NBF0QiReSDPWa6yJ1WOpi-mxzoTXvKmuTtJO0Keiq_DBxeCB7Ya9S_9iJha1X6HS86jSoZkGfOjF9R9UFFSfvrwj2p6Q4Tw14nAMyEtU_0LR3uXvm7KvuJL0-oGuGOfALDA17_4yRk3jnDaUzG6Dz0mbiZVTkV7RP81qteJB_IG_4b1Dg3VSwUbMS__UZaghh3ttNcHy2BAEoQj-QdR39efrMLZvLwXoOc_wWFBPDPUKWlEYCbAvjUAh6CpFxz1hGtjnA8OA', 'width': 3024}], 'place_id': 'ChIJua3HK9UH9YgRgdETQmmb5Wg', 'plus_code': {'compound_code': 'RMRQ+J7 Atlanta, Georgia', 'global_code': '865QRMRQ+J7'}, 'price_level': 1, 'rating': 4.5, 'reference': 'ChIJua3HK9UH9YgRgdETQmmb5Wg', 'scope': 'GOOGLE', 'types': ['gas_station', 'point_of_interest', 'establishment'], 'user_ratings_total': 240, 'vicinity': '2901 Clairmont Rd, Atlanta'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 33.8428245, 'lng': -84.31152379999999}, 'viewport': {'northeast': {'lat': 33.84403577989272, 'lng': -84.31043257010727}, 'southwest': {'lat': 33.84133612010728, 'lng': -84.3131322298927}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'name': "Sam's Club Bakery", 'opening_hours': {'open_no ...
# Name: Sam's Club
# Types: ['electronics_store', 'bakery', 'liquor_store', 'food', 'store', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Gas Station
# Types: ['gas_station', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Bakery
# Types: ['bakery', 'food', 'store', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Tire & Battery
# Types: ['store', 'car_repair', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Pharmacy
# Types: ['pharmacy', 'health', 'store', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Floral
# Types: ['florist', 'store', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Cafe
# Types: ['cafe', 'meal_takeaway', 'restaurant', 'food', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Optical Center
# Types: ['health', 'point_of_interest', 'establishment']
#
# Name: Sam's Club Hearing Aid Center
# Types: ['health', 'store', 'point_of_interest', 'establishment']

# %%
def get_place_text(query, latitude, longitude, radius=5000):
    """
    Use Google Places API v1 (New) to search for nearby places by keyword.
    """
    url = "https://places.googleapis.com/v1/places:searchText"

    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": (
            "places.displayName,"
            "places.formattedAddress,"
            "places.location,"
            "places.types"
        )
    }

    body = {
        "locationBias": {
            "circle": {
                "center": {
                    "latitude": latitude,
                    "longitude": longitude
                },
                "radius": radius
            }
        },
        "textQuery": query,
        "maxResultCount": 20  # Optional, max allowed per request
    }

    response = requests.post(url, headers=headers, json=body)
    data = response.json()

    # Print API response for debugging
    print("API Response:", data)

    if "places" not in data:
        print("No places found or error occurred.")
        return []

    for place in data["places"]:
        name = place.get("displayName", {}).get("text", "N/A")
        address = place.get("formattedAddress", "N/A")
        types = place.get("types", [])
        print(f"Name: {name}")
        print(f"Address: {address}")
        print(f"Types: {types}\n")

    return data["places"]

# %%
get_place_text("YMCA", 33.78, -84.39)
# Out:
# API Response: {'places': [{'types': ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '1160 Moores Mill Rd NW, Atlanta, GA 30327, USA', 'location': {'latitude': 33.8312738, 'longitude': -84.4251855}, 'displayName': {'text': 'Carl E. Sanders Family YMCA at Buckhead', 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'government_office', 'school', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '555 Luckie St NW, Atlanta, GA 30313, USA', 'location': {'latitude': 33.770347199999996, 'longitude': -84.3954736}, 'displayName': {'text': 'Arthur M. Blank Family Youth YMCA', 'languageCode': 'en'}}, {'types': ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '275 Eva Davis Way SE, Atlanta, GA 30317, USA', 'location': {'latitude': 33.7461736, 'longitude': -84.3150162}, 'displayName': {'text': 'East Lake Family YMCA', 'languageCode': 'en'}}, {'types': ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '1100 Clairemont Ave, Decatur, GA 30030, USA', 'location': {'latitude': 33.7873728, 'longitude': -84.3074803}, 'displayName': {'text': 'Decatur Family YMCA', 'languageCode': 'en'}}, {'types': ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '1600 Pryor Rd SW, Atlanta, GA 30315, USA', 'location': {'latitude': 33.710513999999996, 'longitude': -84.39297479999999}, 'displayName': {'text': 'The Villages at Carver Family YMCA', 'languageCode': 'en'}}, {'types': ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '455 Lee St SW, Atlanta, GA 30310, USA', 'location': {'latitude': 33.7423703, 'longitude': -84.41423759999999}, 'displayName': {'text': 'YMCA at Morehouse School of Medicine', 'languageCode': 'en'}}, {'types': ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '3692 Ashford Dunwoody Rd, Atlanta, GA 30319, USA', 'location': {'latitude': 33.898893, 'longitude': -84.333051}, 'displayName': {'text': 'Cowart Family YMCA', 'languageCode': 'en'}}, {'types': ['point_of_interest', 'establishment'], 'formattedAddress': '569 M.L.K. Jr Dr NW, Atlanta, GA 30314, USA', 'location': {'latitude': 33.7548726, 'longitude': -84.4057275}, 'displayName': {'text': 'YMCA of Metro Atlanta Administrative Offices', 'languageCode': 'en'}}, {'types': ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '2220 Campbellton Rd SW, Atlanta, GA 30311, USA', 'location': {'latitude': 33.7046089, 'longitude': -84.46168229999999}, 'displayName': {'text': 'Andrew & Walter Young Family YMCA', 'languageCode': 'en'}}, {'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': '1015 Donald Lee Hollowell Pkwy NW, Atlanta, GA 30318, USA', 'location': {'latitude': 33.7736267, 'longitude': -84.4206293}, 'displayName': {'text': 'The Y at Good Sam', 'languageCode': 'en'}}, {'types': ['government_office', 'point_of_interest', 'establishment'], 'formattedAddress': '1765 Memorial Dr SE, Atlanta, GA 30317, USA', 'location': {'latitude': 33.7472132, 'longitude': -84.3290253}, 'displayName': {'text': 'YMCA Youth and Teen Development Center', 'languageCode': 'en'}}, {'types': ['point_of_interest', 'establishment'], 'formattedAddress': '2565 Snapfinger Rd, Decatur, GA 30034, USA', 'location': {'latitude': 33.7046231, 'longitude': -84.217637}, 'displayName': {'text': 'South DeKalb Family YMCA', 'languageCode': 'en'}}, {'types': ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': '1765 Memorial Dr SE, Atlanta, GA 30317, USA', 'location': {'latitude': 33.7460553, 'longitude': -84.314833}, 'displayName': {'tex ...
# Name: Carl E. Sanders Family YMCA at Buckhead
# Address: 1160 Moores Mill Rd NW, Atlanta, GA 30327, USA
# Types: ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: Arthur M. Blank Family Youth YMCA
# Address: 555 Luckie St NW, Atlanta, GA 30313, USA
# Types: ['preschool', 'child_care_agency', 'government_office', 'school', 'health', 'point_of_interest', 'establishment']
#
# Name: East Lake Family YMCA
# Address: 275 Eva Davis Way SE, Atlanta, GA 30317, USA
# Types: ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: Decatur Family YMCA
# Address: 1100 Clairemont Ave, Decatur, GA 30030, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: The Villages at Carver Family YMCA
# Address: 1600 Pryor Rd SW, Atlanta, GA 30315, USA
# Types: ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: YMCA at Morehouse School of Medicine
# Address: 455 Lee St SW, Atlanta, GA 30310, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: Cowart Family YMCA
# Address: 3692 Ashford Dunwoody Rd, Atlanta, GA 30319, USA
# Types: ['gym', 'government_office', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: YMCA of Metro Atlanta Administrative Offices
# Address: 569 M.L.K. Jr Dr NW, Atlanta, GA 30314, USA
# Types: ['point_of_interest', 'establishment']
#
# Name: Andrew & Walter Young Family YMCA
# Address: 2220 Campbellton Rd SW, Atlanta, GA 30311, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: The Y at Good Sam
# Address: 1015 Donald Lee Hollowell Pkwy NW, Atlanta, GA 30318, USA
# Types: ['community_center', 'event_venue', 'point_of_interest', 'establishment']
#
# Name: YMCA Youth and Teen Development Center
# Address: 1765 Memorial Dr SE, Atlanta, GA 30317, USA
# Types: ['government_office', 'point_of_interest', 'establishment']
#
# Name: South DeKalb Family YMCA
# Address: 2565 Snapfinger Rd, Decatur, GA 30034, USA
# Types: ['point_of_interest', 'establishment']
#
# Name: YMCA East Lake Pool
# Address: 1765 Memorial Dr SE, Atlanta, GA 30317, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: Wade Walker Family YMCA
# Address: 5605 Rockbridge Rd SW, Stone Mountain, GA 30088, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: East Lake Branch YMCA
# Address: 275 E Lake Blvd SE, Atlanta, GA 30317, USA
# Types: ['point_of_interest', 'establishment']
#
# Name: Chattahoochee YMCA Head Start Academy
# Address: 2751 Peyton Rd NW, Atlanta, GA 30318, USA
# Types: ['beauty_salon', 'point_of_interest', 'establishment']
#
# Name: McCleskey-East Cobb Family YMCA
# Address: 1055 E Piedmont Rd, Marietta, GA 30062, USA
# Types: ['gym', 'sports_complex', 'wellness_center', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: Dean Rusk YMCA Head Start Academy
# Address: 433 Peeples St SW, Atlanta, GA 30310, USA
# Types: ['preschool', 'child_care_agency', 'roofing_contractor', 'general_contractor', 'school', 'point_of_interest', 'establishment']
#
# Name: Robert D. Fowler Family YMCA
# Address: 5600 W Jones Bridge Rd, Peachtree Corners, GA 30092, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
#
# Name: Georgia Tech Campus Recreation Center
# Address: 750 Ferst Dr, Atlanta, GA 30332, USA
# Types: ['gym', 'sports_activity_location', 'health', 'point_of_interest', 'establishment']
# [{'types': ['gym',
#    'government_office',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1160 Moores Mill Rd NW, Atlanta, GA 30327, USA',
#   'location': {'latitude': 33.8312738, 'longitude': -84.4251855},
#   'displayName': {'text': 'Carl E. Sanders Family YMCA at Buckhead',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'government_office',
#    'school',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '555 Luckie St NW, Atlanta, GA 30313, USA',
#   'location': {'latitude': 33.770347199999996, 'longitude': -84.3954736},
#   'displayName': {'text': 'Arthur M. Blank Family Youth YMCA',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'government_office',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '275 Eva Davis Way SE, Atlanta, GA 30317, USA',
#   'location': {'latitude': 33.7461736, 'longitude': -84.3150162},
#   'displayName': {'text': 'East Lake Family YMCA', 'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1100 Clairemont Ave, Decatur, GA 30030, USA',
#   'location': {'latitude': 33.7873728, 'longitude': -84.3074803},
#   'displayName': {'text': 'Decatur Family YMCA', 'languageCode': 'en'}},
#  {'types': ['gym',
#    'government_office',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1600 Pryor Rd SW, Atlanta, GA 30315, USA',
#   'location': {'latitude': 33.710513999999996,
#    'longitude': -84.39297479999999},
#   'displayName': {'text': 'The Villages at Carver Family YMCA',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '455 Lee St SW, Atlanta, GA 30310, USA',
#   'location': {'latitude': 33.7423703, 'longitude': -84.41423759999999},
#   'displayName': {'text': 'YMCA at Morehouse School of Medicine',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'government_office',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '3692 Ashford Dunwoody Rd, Atlanta, GA 30319, USA',
#   'location': {'latitude': 33.898893, 'longitude': -84.333051},
#   'displayName': {'text': 'Cowart Family YMCA', 'languageCode': 'en'}},
#  {'types': ['point_of_interest', 'establishment'],
#   'formattedAddress': '569 M.L.K. Jr Dr NW, Atlanta, GA 30314, USA',
#   'location': {'latitude': 33.7548726, 'longitude': -84.4057275},
#   'displayName': {'text': 'YMCA of Metro Atlanta Administrative Offices',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '2220 Campbellton Rd SW, Atlanta, GA 30311, USA',
#   'location': {'latitude': 33.7046089, 'longitude': -84.46168229999999},
#   'displayName': {'text': 'Andrew & Walter Young Family YMCA',
#    'languageCode': 'en'}},
#  {'types': ['community_center',
#    'event_venue',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1015 Donald Lee Hollowell Pkwy NW, Atlanta, GA 30318, USA',
#   'location': {'latitude': 33.7736267, 'longitude': -84.4206293},
#   'displayName': {'text': 'The Y at Good Sam', 'languageCode': 'en'}},
#  {'types': ['government_office', 'point_of_interest', 'establishment'],
#   'formattedAddress': '1765 Memorial Dr SE, Atlanta, GA 30317, USA',
#   'location': {'latitude': 33.7472132, 'longitude': -84.3290253},
#   'displayName': {'text': 'YMCA Youth and Teen Development Center',
#    'languageCode': 'en'}},
#  {'types': ['point_of_interest', 'establishment'],
#   'formattedAddress': '2565 Snapfinger Rd, Decatur, GA 30034, USA',
#   'location': {'latitude': 33.7046231, 'longitude': -84.217637},
#   'displayName': {'text': 'South DeKalb Family YMCA', 'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1765 Memorial Dr SE, Atlanta, GA 30317, USA',
#   'location': {'latitude': 33.7460553, 'longitude': -84.314833},
#   'displayName': {'text': 'YMCA East Lake Pool', 'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '5605 Rockbridge Rd SW, Stone Mountain, GA 30088, USA',
#   'location': {'latitude': 33.7864497, 'longitude': -84.1660387},
#   'displayName': {'text': 'Wade Walker Family YMCA', 'languageCode': 'en'}},
#  {'types': ['point_of_interest', 'establishment'],
#   'formattedAddress': '275 E Lake Blvd SE, Atlanta, GA 30317, USA',
#   'location': {'latitude': 33.7460672, 'longitude': -84.3148358},
#   'displayName': {'text': 'East Lake Branch YMCA', 'languageCode': 'en'}},
#  {'types': ['beauty_salon', 'point_of_interest', 'establishment'],
#   'formattedAddress': '2751 Peyton Rd NW, Atlanta, GA 30318, USA',
#   'location': {'latitude': 33.8088057, 'longitude': -84.4776467},
#   'displayName': {'text': 'Chattahoochee YMCA Head Start Academy',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_complex',
#    'wellness_center',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1055 E Piedmont Rd, Marietta, GA 30062, USA',
#   'location': {'latitude': 33.977593299999995, 'longitude': -84.4811818},
#   'displayName': {'text': 'McCleskey-East Cobb Family YMCA',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'roofing_contractor',
#    'general_contractor',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '433 Peeples St SW, Atlanta, GA 30310, USA',
#   'location': {'latitude': 33.7429664, 'longitude': -84.4215339},
#   'displayName': {'text': 'Dean Rusk YMCA Head Start Academy',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '5600 W Jones Bridge Rd, Peachtree Corners, GA 30092, USA',
#   'location': {'latitude': 33.978686599999996,
#    'longitude': -84.22741549999999},
#   'displayName': {'text': 'Robert D. Fowler Family YMCA',
#    'languageCode': 'en'}},
#  {'types': ['gym',
#    'sports_activity_location',
#    'health',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '750 Ferst Dr, Atlanta, GA 30332, USA',
#   'location': {'latitude': 33.7755602, 'longitude': -84.40356510000001},
#   'displayName': {'text': 'Georgia Tech Campus Recreation Center',
#    'languageCode': 'en'}}]

# %%
def get_place_types_v1_by_type(place_type, latitude, longitude, radius=5000):
    url = "https://places.googleapis.com/v1/places:searchNearby"

    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": (
            "places.displayName,"
            "places.formattedAddress,"
            "places.location,"
            "places.types"
        )
    }

    body = {
        "includedTypes": [place_type],  # Must be a valid place type
        "locationRestriction": {
            "circle": {
                "center": {
                    "latitude": latitude,
                    "longitude": longitude
                },
                "radius": radius
            }
        },
        "maxResultCount": 20
    }

    response = requests.post(url, headers=headers, json=body)
    data = response.json()

    print("API Response:", data)

    if "places" not in data:
        print("No places found or error occurred.")
        return []

    for place in data["places"]:
        name = place.get("displayName", {}).get("text", "N/A")
        address = place.get("formattedAddress", "N/A")
        types = place.get("types", [])
        print(f"Name: {name}")
        print(f"Address: {address}")
        print(f"Types: {types}\n")

    return data["places"]

# %%
get_place_types_v1_by_type("child_care_agency", 33.78, -84.39)
# Out:
# API Response: {'places': [{'types': ['department_store', 'shoe_store', 'child_care_agency', 'electronics_store', 'clothing_store', 'furniture_store', 'home_improvement_store', 'home_goods_store', 'store', 'point_of_interest', 'establishment'], 'formattedAddress': '375 18th St NW, Atlanta, GA 30363, USA', 'location': {'latitude': 33.7932856, 'longitude': -84.39933669999999}, 'displayName': {'text': 'Target', 'languageCode': 'en'}}, {'types': ['department_store', 'shoe_store', 'child_care_agency', 'electronics_store', 'clothing_store', 'furniture_store', 'home_improvement_store', 'home_goods_store', 'store', 'point_of_interest', 'establishment'], 'formattedAddress': '1275 Caroline St NE, Atlanta, GA 30307, USA', 'location': {'latitude': 33.7569541, 'longitude': -84.3463134}, 'displayName': {'text': 'Target', 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'church', 'place_of_worship', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '1328 Peachtree St NE, Atlanta, GA 30309, USA', 'location': {'latitude': 33.7906027, 'longitude': -84.3866122}, 'displayName': {'text': 'First Presbyterian Church of Atlanta', 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '1509 S Ponce De Leon Ave NE, Atlanta, GA 30307, USA', 'location': {'latitude': 33.7731723, 'longitude': -84.3379362}, 'displayName': {'text': 'The Paideia School', 'languageCode': 'en'}}, {'types': ['childrens_camp', 'preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '345 10th St NE, Atlanta, GA 30309, USA', 'location': {'latitude': 33.7815332, 'longitude': -84.37593969999999}, 'displayName': {'text': "The Children's School", 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '644 W Peachtree St NW, Atlanta, GA 30308, USA', 'location': {'latitude': 33.7720212, 'longitude': -84.3879709}, 'displayName': {'text': "Bright Horizons at All Saints'", 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '225 James P Brawley Dr NW, Atlanta, GA 30314, USA', 'location': {'latitude': 33.761069299999996, 'longitude': -84.4116282}, 'displayName': {'text': 'Michael R. Hollis Innovation Academy', 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '519 Memorial Dr SE Suite A-14, Atlanta, GA 30312, USA', 'location': {'latitude': 33.7462996, 'longitude': -84.37084779999999}, 'displayName': {'text': 'Primrose School of Grant Park', 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '650 North Avenue NE Suite 206, Atlanta, GA 30308, USA', 'location': {'latitude': 33.771976599999995, 'longitude': -84.3668886}, 'displayName': {'text': 'The Suzuki School', 'languageCode': 'en'}}, {'types': ['primary_school', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '112 Boulevard NE, Atlanta, GA 30312, USA', 'location': {'latitude': 33.7571039, 'longitude': -84.3724896}, 'displayName': {'text': 'Hope-Hill Elementary School', 'languageCode': 'en'}}, {'types': ['summer_camp_organizer', 'preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '1080 Spring St NW, Atlanta, GA 30309, USA', 'location': {'latitude': 33.7841552, 'longitude': -84.3895711}, 'displayName': {'text': 'The Goddard School of Atlanta (Midtown)', 'languageCode': 'en'}}, {'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '516 Ponce De Leon Ave NE, Atlanta, GA 30308, USA', 'location': {'latitude': 33.774333999999996, 'longitude': ...
# Name: Target
# Address: 375 18th St NW, Atlanta, GA 30363, USA
# Types: ['department_store', 'shoe_store', 'child_care_agency', 'electronics_store', 'clothing_store', 'furniture_store', 'home_improvement_store', 'home_goods_store', 'store', 'point_of_interest', 'establishment']
#
# Name: Target
# Address: 1275 Caroline St NE, Atlanta, GA 30307, USA
# Types: ['department_store', 'shoe_store', 'child_care_agency', 'electronics_store', 'clothing_store', 'furniture_store', 'home_improvement_store', 'home_goods_store', 'store', 'point_of_interest', 'establishment']
#
# Name: First Presbyterian Church of Atlanta
# Address: 1328 Peachtree St NE, Atlanta, GA 30309, USA
# Types: ['preschool', 'child_care_agency', 'church', 'place_of_worship', 'school', 'point_of_interest', 'establishment']
#
# Name: The Paideia School
# Address: 1509 S Ponce De Leon Ave NE, Atlanta, GA 30307, USA
# Types: ['preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment']
#
# Name: The Children's School
# Address: 345 10th St NE, Atlanta, GA 30309, USA
# Types: ['childrens_camp', 'preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment']
#
# Name: Bright Horizons at All Saints'
# Address: 644 W Peachtree St NW, Atlanta, GA 30308, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Michael R. Hollis Innovation Academy
# Address: 225 James P Brawley Dr NW, Atlanta, GA 30314, USA
# Types: ['preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment']
#
# Name: Primrose School of Grant Park
# Address: 519 Memorial Dr SE Suite A-14, Atlanta, GA 30312, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: The Suzuki School
# Address: 650 North Avenue NE Suite 206, Atlanta, GA 30308, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Hope-Hill Elementary School
# Address: 112 Boulevard NE, Atlanta, GA 30312, USA
# Types: ['primary_school', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: The Goddard School of Atlanta (Midtown)
# Address: 1080 Spring St NW, Atlanta, GA 30309, USA
# Types: ['summer_camp_organizer', 'preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Kiddie Academy of Midtown
# Address: 516 Ponce De Leon Ave NE, Atlanta, GA 30308, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Atlanta Montessori International School - Druid Hills
# Address: 1215 S Ponce De Leon Ave NE, Atlanta, GA 30306, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Primrose School of Midtown at Colony Square
# Address: 1197 Peachtree St NE Suite 554, Atlanta, GA 30361, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: The Children's Children's Campus @ Georgia Tech
# Address: 251 10th St NE Building F Building F, Atlanta, GA 30318, USA
# Types: ['summer_camp_organizer', 'preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Bright Horizons at Atlantic Station
# Address: 1381 Market St NW, Atlanta, GA 30363, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Riverstones Academy - Morningside
# Address: 1140 University Dr NE, Atlanta, GA 30306, USA
# Types: ['preschool', 'childrens_camp', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: Sheltering Arms Model Center
# Address: 385 Centennial Olympic Park Dr NW, Atlanta, GA 30313, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
#
# Name: International Montessori Academy
# Address: 1240 Euclid Ave NE, Atlanta, GA 30307, USA
# Types: ['preschool', 'child_care_agency', 'primary_school', 'school', 'point_of_interest', 'establishment']
#
# Name: Intown Jewish Preschool
# Address: 604 Cooledge Ave NE, Atlanta, GA 30306, USA
# Types: ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment']
# [{'types': ['department_store',
#    'shoe_store',
#    'child_care_agency',
#    'electronics_store',
#    'clothing_store',
#    'furniture_store',
#    'home_improvement_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '375 18th St NW, Atlanta, GA 30363, USA',
#   'location': {'latitude': 33.7932856, 'longitude': -84.39933669999999},
#   'displayName': {'text': 'Target', 'languageCode': 'en'}},
#  {'types': ['department_store',
#    'shoe_store',
#    'child_care_agency',
#    'electronics_store',
#    'clothing_store',
#    'furniture_store',
#    'home_improvement_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1275 Caroline St NE, Atlanta, GA 30307, USA',
#   'location': {'latitude': 33.7569541, 'longitude': -84.3463134},
#   'displayName': {'text': 'Target', 'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'church',
#    'place_of_worship',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1328 Peachtree St NE, Atlanta, GA 30309, USA',
#   'location': {'latitude': 33.7906027, 'longitude': -84.3866122},
#   'displayName': {'text': 'First Presbyterian Church of Atlanta',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'primary_school',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1509 S Ponce De Leon Ave NE, Atlanta, GA 30307, USA',
#   'location': {'latitude': 33.7731723, 'longitude': -84.3379362},
#   'displayName': {'text': 'The Paideia School', 'languageCode': 'en'}},
#  {'types': ['childrens_camp',
#    'preschool',
#    'child_care_agency',
#    'primary_school',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '345 10th St NE, Atlanta, GA 30309, USA',
#   'location': {'latitude': 33.7815332, 'longitude': -84.37593969999999},
#   'displayName': {'text': "The Children's School", 'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '644 W Peachtree St NW, Atlanta, GA 30308, USA',
#   'location': {'latitude': 33.7720212, 'longitude': -84.3879709},
#   'displayName': {'text': "Bright Horizons at All Saints'",
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'primary_school',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '225 James P Brawley Dr NW, Atlanta, GA 30314, USA',
#   'location': {'latitude': 33.761069299999996, 'longitude': -84.4116282},
#   'displayName': {'text': 'Michael R. Hollis Innovation Academy',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '519 Memorial Dr SE Suite A-14, Atlanta, GA 30312, USA',
#   'location': {'latitude': 33.7462996, 'longitude': -84.37084779999999},
#   'displayName': {'text': 'Primrose School of Grant Park',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '650 North Avenue NE Suite 206, Atlanta, GA 30308, USA',
#   'location': {'latitude': 33.771976599999995, 'longitude': -84.3668886},
#   'displayName': {'text': 'The Suzuki School', 'languageCode': 'en'}},
#  {'types': ['primary_school',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '112 Boulevard NE, Atlanta, GA 30312, USA',
#   'location': {'latitude': 33.7571039, 'longitude': -84.3724896},
#   'displayName': {'text': 'Hope-Hill Elementary School',
#    'languageCode': 'en'}},
#  {'types': ['summer_camp_organizer',
#    'preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1080 Spring St NW, Atlanta, GA 30309, USA',
#   'location': {'latitude': 33.7841552, 'longitude': -84.3895711},
#   'displayName': {'text': 'The Goddard School of Atlanta (Midtown)',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '516 Ponce De Leon Ave NE, Atlanta, GA 30308, USA',
#   'location': {'latitude': 33.774333999999996, 'longitude': -84.369969},
#   'displayName': {'text': 'Kiddie Academy of Midtown', 'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1215 S Ponce De Leon Ave NE, Atlanta, GA 30306, USA',
#   'location': {'latitude': 33.7733482, 'longitude': -84.34742},
#   'displayName': {'text': 'Atlanta Montessori International School - Druid Hills',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1197 Peachtree St NE Suite 554, Atlanta, GA 30361, USA',
#   'location': {'latitude': 33.7877156, 'longitude': -84.3820715},
#   'displayName': {'text': 'Primrose School of Midtown at Colony Square',
#    'languageCode': 'en'}},
#  {'types': ['summer_camp_organizer',
#    'preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '251 10th St NE Building F Building F, Atlanta, GA 30318, USA',
#   'location': {'latitude': 33.7831036, 'longitude': -84.3965334},
#   'displayName': {'text': "The Children's Children's Campus @ Georgia Tech",
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1381 Market St NW, Atlanta, GA 30363, USA',
#   'location': {'latitude': 33.7927805, 'longitude': -84.3943875},
#   'displayName': {'text': 'Bright Horizons at Atlantic Station',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'childrens_camp',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1140 University Dr NE, Atlanta, GA 30306, USA',
#   'location': {'latitude': 33.7914719, 'longitude': -84.3491402},
#   'displayName': {'text': 'Riverstones Academy - Morningside',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '385 Centennial Olympic Park Dr NW, Atlanta, GA 30313, USA',
#   'location': {'latitude': 33.7658628, 'longitude': -84.3916769},
#   'displayName': {'text': 'Sheltering Arms Model Center',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'primary_school',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '1240 Euclid Ave NE, Atlanta, GA 30307, USA',
#   'location': {'latitude': 33.766935499999995,
#    'longitude': -84.34778000000001},
#   'displayName': {'text': 'International Montessori Academy',
#    'languageCode': 'en'}},
#  {'types': ['preschool',
#    'child_care_agency',
#    'school',
#    'point_of_interest',
#    'establishment'],
#   'formattedAddress': '604 Cooledge Ave NE, Atlanta, GA 30306, USA',
#   'location': {'latitude': 33.782814699999996,
#    'longitude': -84.36766539999999},
#   'displayName': {'text': 'Intown Jewish Preschool', 'languageCode': 'en'}}]

# %%
DESIRABLE_AMENITIES = {
    "national_big_box_store": {"group": 1, "google_type": "department_store", "name_contain": ["Walmart", "Target", "Costco", "BJ's", "Sam's Club"]}, 
    "retail_store": {"group": 2, "google_type": ["clothing_store", "home_goods_store"]},
    "grocery_store": {"group": 1, "google_type": ["grocery_or_supermarket", 'supermarket'], "type_not_contains": ['convience_store']}, 
    "restaurant": {"group": 2, "google_type": "retaurant"},
    "hospital": {"group": 1, "google_type": "hospital", "name_not_contains": ["Outpatient"]}, 
    "medical_clinic": {"group": 1, "google_type": "doctor", "name_contains": ["urgent care", "medical clinic", "immediate care", "physicians", "dentist"]}, 
    "pharmacy": {"group": 1, "google_type": "pharmacy"},
    "licensed_childcare": {"group": 1},
    "technical_college": {"group": 2},
    "school": {"group": 1, "google_type": ["primary_school", "secondary_school", "school"]},
    "town_square": {"group": 1, "google_type": ['city_hall', 'courthouse'] },
    "community_center": {"group": 1, "google_type": ["community_center", 'gym', 'pool']},
    "large_public_park": {"group": 1, "google_type": "park"},
    "small_public_park": {"group": 2, "google_type": "park"},
    "library": {"group": 1, "google_type": "library"},
    "fire_police_station": {"group": 2, "google_type": ["fire_station", "police"]},
    "bank": {"group": 2, "google_type": "bank"}, 
    "place_of_worship": {"group": 2, "google_type": "place_of_worship"},
    "post_office": {"group": 2, "google_type": "post_office"},
}

UNDESIRABLE_ACTIVITIES = {
    "auto_repair_station": {"google_type": "car_repair"},
    "commercial_livestock": {"google_type": "farm"},
    "excessive_light": {"google_type": ["casino", "stadium", 'night_club']},
    "excessive_noise": {'google_type': ['airport']}, 
    "laundry_facility": {"google_type": "laundry"},
    "gas_station": {"google_type": "gas_station"},
}


# Junk yards
# dumps
# landfill
# materials storage areas
# commercial livestock operations 
# Odor producing facilities 
# Potential or existing environmental hazards: 
#     - chemical activities
#     - heavy manufacturing activities
#     - Industrial development 
#     - Facilities listed in federal or state hazardous investory databases
#     - Gas stations with history of leaking underground storage tanks
#     - dry clearners with history of contamination
# Abandoned houses or buildings 
# Deteriorting houses or buildings
# Food deserts 

# """
# 2020_cdr_consumer_and_commercial_use_information
# - TRI Facility Name
# - Year
# - Census Tract
# - Latitude
# - Longitude 
# - Releases (lb)
# - Waste Managed (lb)
# - RSEI Hazard
# - # of TRI Facilities


# 2020_cdr_industrial_processing_and_use_information
# - CHEMICAL NAME
# - DOMESTIC PARENT COMPANY NAME
# - SITE NAME
# - SITE LATITUDE
# - SITE LONGITUDE

# food_access_research_atlas
# - CensusTract
# - Urban 
# - 

# Facilities_GA
# - Latitude
# - Longitude
# - Ope USTs


# """


# """
# Have
# EPA TRI Dataset 



# chemical_factory 
# industrial_facility
# waste_management
# hazardous_site

# food desert - USDA Food Access Research Atlas


# Dont have yet

# EPA RCRAInfo
#     junkyard
#     dump
#     landfill

# municipal code violation databases or tax assessor data
#     abandoned_building
#     deteriorated_housing 

# EPA FRS Database
#     gas stations with underground leakage 
#     dry cleaner contaminatio 

#     odor producing facilities

#     Floodplain, Wetlands, Soil Unsuitability - FEMA Flood Maps and USGS Soil Data
# """

# %%
def find_places_nearby(lat, lon, place_type, radius_meters=10000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": f"{lat},{lon}",
        "radius": radius_meters,
        "type": place_type,
        "key":  MY_API_KEY
    }

    response = requests.get(url, params=params).json()
    results = response.get("results", [])

    places = []
    for r in results:
        p_lat = r["geometry"]["location"]["lat"]
        p_lon = r["geometry"]["location"]["lng"]
        name = r["name"]
        place_id = r.get("place_id", "")
        types = r.get("types", [])
        places.append({
            "name": name,
            "lat": p_lat,
            "lon": p_lon,
            "types": types,
            "place_id": place_id
        })
    return places

# %%
def filter_places(places, amenity_info):
    """
    Applies the custom filtering logic based on:
      - store_names (include only if name matches)
      - not_contains (exclude if substring appears in name)
      - contains (include only if substring appears in name)
    """
    filtered = places

    # 1) store_names => Keep only places with name containing any item in store_names
    store_names = amenity_info.get("store_names", [])
    if store_names:
        store_names_lower = [s.lower() for s in store_names]
        def matches_store_names(place):
            place_name_l = place["name"].lower()
            # Must match at least one
            return any(s in place_name_l for s in store_names_lower)
        filtered = list(filter(matches_store_names, filtered))

    # 2) not_contains => Exclude if place name contains any item in not_contains
    not_contains_list = amenity_info.get("not_contains", [])
    if not_contains_list:
        not_contains_lower = [x.lower() for x in not_contains_list]
        def exclude_if_contains(place):
            place_name_l = place["name"].lower()
            # If ANY forbidden substring is present, exclude
            return not any(x in place_name_l for x in not_contains_lower)
        filtered = list(filter(exclude_if_contains, filtered))

    # 3) contains => Keep only if place name contains at least one item in 'contains'
    contains_list = amenity_info.get("contains", [])
    if contains_list:
        contains_lower = [c.lower() for c in contains_list]
        def include_if_contains(place):
            place_name_l = place["name"].lower()
            # Include if ANY of the substrings is found
            return any(c in place_name_l for c in contains_lower)
        filtered = list(filter(include_if_contains, filtered))

    return filtered

# %%
def get_distance_matrix_distance(
    origin_lat, origin_lon,
    dest_lat, dest_lon,
    travel_mode="driving",
    api_key= MY_API_KEY
):
    """
    Returns the distance in meters for the specified travel mode (driving, walking, bicycling, transit).
    """
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        "origins": f"{origin_lat},{origin_lon}",
        "destinations": f"{dest_lat},{dest_lon}",
        "mode": travel_mode,    # "driving" or "walking", etc.
        "key": api_key
    }

    response = requests.get(url, params=params).json()
    print(response) 
    try:
        # Distance in meters
        distance_meters = response["rows"][0]["elements"][0]["distance"]["value"]
        return distance_meters
    except (KeyError, IndexError):
        # Handle the case where the response doesn't have the expected structure
        return None

# %%
if __name__ == "__main__":
    YOUR_API_KEY = MY_API_KEY

    origin_lat, origin_lon = 33.7490, -84.3880   
    dest_lat, dest_lon = 33.7374337, -84.4330913      

    driving_distance_m = get_distance_matrix_distance(
        origin_lat, origin_lon,
        dest_lat, dest_lon,
        travel_mode="driving",
        api_key=YOUR_API_KEY
    )

    walking_distance_m = get_distance_matrix_distance(
        origin_lat, origin_lon,
        dest_lat, dest_lon,
        travel_mode="walking",
        api_key=YOUR_API_KEY
    )

    if driving_distance_m is not None:
        print(f"Driving distance: {driving_distance_m} meters (~{driving_distance_m/1609.34:.2f} miles)")
    else:
        print("Could not retrieve driving distance.")

    if walking_distance_m is not None:
        print(f"Walking distance: {walking_distance_m} meters (~{walking_distance_m/1609.34:.2f} miles)")
    else:
        print("Could not retrieve walking distance.")
# Out:
# {'destination_addresses': ['590 Cascade Ave SW, Atlanta, GA 30310, USA'], 'origin_addresses': ['1530 Ridgewood Ln SW, Atlanta, GA 30311, USA'], 'rows': [{'elements': [{'distance': {'text': '5.9 km', 'value': 5888}, 'duration': {'text': '8 mins', 'value': 495}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['590 Cascade Ave SW, Atlanta, GA 30310, USA'], 'origin_addresses': ['1530 Ridgewood Ln SW, Atlanta, GA 30311, USA'], 'rows': [{'elements': [{'distance': {'text': '5.2 km', 'value': 5157}, 'duration': {'text': '1 hour 15 mins', 'value': 4481}, 'status': 'OK'}]}], 'status': 'OK'}
# Driving distance: 5888 meters (~3.66 miles)
# Walking distance: 5157 meters (~3.20 miles)

# %%
def assign_points(distance, group):
    """
    Dynamically assigns points based on amenity group and distance.
    """
    if group == 1:  
        if distance <= 0.5:
            return 2.5
        elif distance <= 1:
            return 2
        elif distance <= 1.5:
            return 1.5
    elif group == 2:  
        if distance <= 0.5:
            return 2
        elif distance <= 1:
            return 1.5
        elif distance <= 2.5:
            return 1
    return 0

# %%
# Compute distance between two locations
def get_distance(lat1, lon1, lat2, lon2):
    return geodesic((lat1, lon1), (lat2, lon2)).miles

# Compute desirability score
def calculate_site_score(site_lat, site_lon, amenities_df, undesirable_df):
    total_points = 0
    deductions = 0

    for _, row in amenities_df.iterrows():
        amenity_type = row["amenity_type"]
        amenity_lat, amenity_lon = row["latitude"], row["longitude"]
        
        if amenity_type in DESIRABLE_AMENITIES:
            distance = get_distance(site_lat, site_lon, amenity_lat, amenity_lon)
            group = DESIRABLE_AMENITIES[amenity_type]["group"]
            points = assign_points(distance, group)
            total_points += points

    for _, row in undesirable_df.iterrows():
        undesired_lat, undesired_lon = row["latitude"], row["longitude"]
        distance = get_distance(site_lat, site_lon, undesired_lat, undesired_lon)
        if distance <= 0.25:
            deductions += 2

    final_score = max(0, total_points - deductions)
    return {"total_points": total_points, "deductions": deductions, "final_score": final_score}

# Example site coordinates
site_latitude = 33.7490
site_longitude = -84.3880

# Load datasets
amenities_df = pd.read_csv("../../data/processed/desirable_amenities.csv")
undesirable_df = pd.read_csv("../../data/processed/undesirable_activities.csv")

# Compute score
score_info = calculate_site_score(site_latitude, site_longitude, amenities_df, undesirable_df)

print("Total Points (Desirable):", score_info["total_points"])
print("Deductions (Undesirable):", score_info["deductions"])
print("Final Score:", score_info["final_score"])

# %%
QUERIES = [
    "community center",
    "recreation center",
    "YMCA",
    "Boys & Girls Club",
    "public pool",
    "senior center",
    "multipurpose facility"
]

# %%
MIN_LAT = 30.35
MAX_LAT = 35.00
MIN_LON = -85.60
MAX_LON = -80.75

# Step size for lat/lon grid
STEP = 0.15

# Radius in meters for each text search
RADIUS = 10000

# %%
import time

# %%
def text_search(query, lat, lon, api_key):
    """
    Perform a Places Text Search for a given query, centered at (lat, lon),
    with a fixed radius. This function returns ALL pages (up to 60 results).
    """
    all_results = []
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

    # Initial parameters
    params = {
        "query": query,
        "location": f"{lat},{lon}",
        "radius": RADIUS,
        "key": api_key
    }

    while True:
        resp = requests.get(url, params=params)
        data = resp.json()

        if data.get("status") not in ("OK", "ZERO_RESULTS"):
            print(f"Warning: text_search got status={data.get('status')}. "
                  f"Error message: {data.get('error_message', '')}")
            break

        results = data.get("results", [])
        all_results.extend(results)

        # Check if there's more results to page through
        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break

        # Google requires a short pause before using next_page_token
        time.sleep(2)
        # Set next_page_token for next iteration
        params["pagetoken"] = next_page_token

    return all_results

# %%
def main():
    # This dictionary will hold places keyed by place_id
    # to avoid duplicates across multiple queries and grid points.
    places_dict = {}

    # Loop over each query
    for query in QUERIES:
        print(f"\n=== Searching for: '{query}' ===\n")
        # Loop over lat/lon grid
        lat = MIN_LAT
        while lat <= MAX_LAT:
            lon = MIN_LON
            while lon <= MAX_LON:
                print(f" Searching around lat={lat:.2f}, lon={lon:.2f}")
                results = text_search(query, lat, lon, API_KEY)
                print(f"  -> Found {len(results)} results")

                for place in results:
                    pid = place["place_id"]
                    if pid not in places_dict:
                        # Extract relevant data
                        name = place.get("name")
                        geometry = place.get("geometry", {})
                        loc = geometry.get("location", {})
                        place_lat = loc.get("lat")
                        place_lon = loc.get("lng")

                        types = place.get("types", [])
                        vicinity = place.get("formatted_address") or place.get("vicinity", "")
                        business_status = place.get("business_status", "")

                        places_dict[pid] = {
                            "amenity_key": "community_center",
                            "place_id": pid,
                            "name": name,
                            "lat": place_lat,
                            "lon": place_lon,
                            "types": "|".join(types),  # store as pipe-separated
                            "vicinity": vicinity,
                            "business_status": business_status
                        }

                lon += STEP
            lat += STEP

    # Write out to CSV
    output_filename = "../../data/preprocessed/scoring_indicators/desirable_undesirable_activities/community_centers_georgia.csv"
    fieldnames = [
        "amenity_key", 
        "place_id", 
        "name", 
        "lat", 
        "lon", 
        "types", 
        "vicinity", 
        "business_status"
    ]

    with open(output_filename, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for _, row in places_dict.items():
            writer.writerow(row)

    print(f"\nDone! Wrote {len(places_dict)} unique places to '{output_filename}'.\n")


if __name__ == "__main__":
    main()
# Out:
# === Searching for: 'community center' ===
#
#  Searching around lat=30.35, lon=-85.60
#   -> Found 60 results
#  Searching around lat=30.35, lon=-85.45
#   -> Found 60 results
#  Searching around lat=30.35, lon=-85.30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 69
#      65     print(f"\nDone! Wrote {len(places_dict)} unique places to '{output_filename}'.\n")
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# Cell In[36], line 15, in main()
#      13 while lon <= MAX_LON:
#      14     print(f" Searching around lat={lat:.2f}, lon={lon:.2f}")
# ---> 15     results = text_search(query, lat, lon, API_KEY)
#      16     print(f"  -> Found {len(results)} results")
#      18     for place in results:
#
# Cell In[33], line 18, in text_search(query, lat, lon, api_key)
#      10 params = {
#      11     "query": query,
#      12     "location": f"{lat},{lon}",
#      13     "radius": RADIUS,
#      14     "key": api_key
#      15 }
#      17 while True:
# ---> 18     resp = requests.get(url, params=params)
#      19     data = resp.json()
#      21     if data.get("status") not in ("OK", "ZERO_RESULTS"):
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/anaconda3/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/homebrew/anaconda3/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/anaconda3/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import csv
import json
import time
import requests
import json
import os
from json import JSONDecodeError

# API_KEY = "YOUR_API_KEY"  # Replace with your Places API key

# Text queries for "community or recreation centers"
QUERIES = [
    "community center",
    "recreation center",
    "YMCA",
    "Boys & Girls Club",
    "public pool",
    "senior center",
    "multipurpose facility"
]

API_KEY = ""

# Approximate bounding box for Georgia
MIN_LAT = 30.35
MAX_LAT = 35.00
MIN_LON = -85.60
MAX_LON = -80.75

# Step size for lat/lon grid
STEP = 0.15

# Radius in meters for each text search
RADIUS = 10000  # ~10 km

# Filenames for our outputs/checkpoints
OUTPUT_CSV = "../../data/preprocessed/scoring_indicators/desirable_undesirable_activities/community_centers_georgia.csv"
CHECKPOINT_JSON = "../../data/preprocessed/scoring_indicators/desirable_undesirable_activities/community_centers_checkpoint.json"

# %%
def ensure_output_directory_exists(csv_path):
    """
    Create all intermediate directories for the given CSV path if they don't exist.
    """
    directory = os.path.dirname(csv_path)
    if directory and not os.path.exists(directory):
        os.makedirs(directory, exist_ok=True)

def initialize_csv(csv_filename):
    """
    If the CSV file does not exist, create it and write the header.
    Otherwise, do nothing.
    """
    # Ensure the directory structure is there
    ensure_output_directory_exists(csv_filename)
    
    if not os.path.exists(csv_filename):
        with open(csv_filename, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            # Write header
            writer.writerow(["amenity_key", "place_id", "name", "lat", "lon", "types", "vicinity", "business_status"])

# %%
def load_checkpoint():
    """
    Load previously discovered places and progress from a JSON file, if it exists.
    Returns a dictionary with at least:
        {
           "places": {},
           "progress": {
               "query_index": 0,
               "lat": MIN_LAT,
               "lon": MIN_LON
           }
        }
    """
    if os.path.exists(CHECKPOINT_JSON):
        try:
            with open(CHECKPOINT_JSON, "r", encoding="utf-8") as f:
                return json.load(f)
        except JSONDecodeError:
            print(f"Warning: {CHECKPOINT_JSON} is empty or invalid JSON. Using fresh checkpoint.")
            # Fall through to return a fresh checkpoint below
        
    # Initialize empty checkpoint if file doesn't exist or is invalid
    return {
        "places": {},
        "progress": {
            "query_index": 0,
            "lat": MIN_LAT,
            "lon": MIN_LON
        }
    }

def save_checkpoint(checkpoint_data):
    """
    Save the checkpoint dictionary to JSON, so we can resume if script is interrupted.
    """
    with open(CHECKPOINT_JSON, "w", encoding="utf-8") as f:
        json.dump(checkpoint_data, f, ensure_ascii=False, indent=2)

def initialize_csv(csv_filename):
    """
    If the CSV file does not exist, create it and write the header.
    Otherwise, do nothing.
    """
    if not os.path.exists(csv_filename):
        with open(csv_filename, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            # Write header
            writer.writerow(["amenity_key", "place_id", "name", "lat", "lon", "types", "vicinity", "business_status"])

def append_row_to_csv(csv_filename, row_dict):
    """
    Append a single row of place data to the CSV.
    """
    with open(csv_filename, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow([
            row_dict["amenity_key"],
            row_dict["place_id"],
            row_dict["name"],
            row_dict["lat"],
            row_dict["lon"],
            row_dict["types"],
            row_dict["vicinity"],
            row_dict["business_status"]
        ])

def text_search(query, lat, lon, api_key):
    """
    Perform a Places Text Search for a given query, centered at (lat, lon),
    with a fixed radius. This function returns ALL pages (up to 60 results).
    """
    all_results = []
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

    # Initial parameters
    params = {
        "query": query,
        "location": f"{lat},{lon}",
        "radius": RADIUS,
        "key": api_key
    }

    while True:
        resp = requests.get(url, params=params)
        data = resp.json()

        if data.get("status") not in ("OK", "ZERO_RESULTS"):
            print(f"Warning: text_search got status={data.get('status')}. "
                  f"Error message: {data.get('error_message', '')}")
            break

        results = data.get("results", [])
        all_results.extend(results)

        # Check if there's more results to page through
        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break

        # Google requires a short pause before using next_page_token
        time.sleep(2)
        # Set next_page_token for next iteration
        params["pagetoken"] = next_page_token

    return all_results

def main():
    # 1. Load checkpoint (discovered places + progress)
    checkpoint = load_checkpoint()
    discovered_places = checkpoint["places"]  # dict: { place_id: {...} }
    progress = checkpoint["progress"]         # dict: { "query_index": int, "lat": float, "lon": float }

    # 2. Initialize CSV (creates file with header if it doesn't exist)
    initialize_csv(OUTPUT_CSV)

    # 3. Start from the progress checkpoint
    current_query_idx = progress["query_index"]
    start_lat = progress["lat"]
    start_lon = progress["lon"]

    # Loop over queries starting from current_query_idx
    for q_idx in range(current_query_idx, len(QUERIES)):
        query = QUERIES[q_idx]
        print(f"\n=== Searching for: '{query}' === (index: {q_idx})\n")

        lat = start_lat
        while lat <= MAX_LAT + 0.000001:  # small epsilon to ensure coverage
            lon = start_lon
            while lon <= MAX_LON + 0.000001:
                print(f"  Searching around lat={lat:.4f}, lon={lon:.4f} for '{query}'")
                results = text_search(query, lat, lon, API_KEY)
                print(f"   -> Found {len(results)} results")

                # Process results
                new_count = 0
                for place in results:
                    pid = place["place_id"]

                    if pid not in discovered_places:
                        # Extract relevant data
                        name = place.get("name", "")
                        geometry = place.get("geometry", {})
                        loc = geometry.get("location", {})
                        place_lat = loc.get("lat")
                        place_lon = loc.get("lng")

                        types = place.get("types", [])
                        vicinity = place.get("formatted_address") or place.get("vicinity", "")
                        business_status = place.get("business_status", "")

                        row_dict = {
                            "amenity_key": "community_center",
                            "place_id": pid,
                            "name": name,
                            "lat": place_lat,
                            "lon": place_lon,
                            "types": "|".join(types),
                            "vicinity": vicinity,
                            "business_status": business_status
                        }

                        # Add to our in-memory dictionary
                        discovered_places[pid] = row_dict
                        new_count += 1

                        # Append row to CSV immediately
                        append_row_to_csv(OUTPUT_CSV, row_dict)

                print(f"   -> {new_count} new places added.\n")

                # Update checkpoint with new progress
                progress["query_index"] = q_idx
                progress["lat"] = lat
                progress["lon"] = lon
                checkpoint["places"] = discovered_places
                checkpoint["progress"] = progress
                save_checkpoint(checkpoint)

                lon += STEP

            # Once we've finished the row of longitudes, reset to the MIN_LON for next row
            start_lon = MIN_LON
            lat += STEP

        # Once we finish a query, reset lat/lon to the bounding-box minimum for the next query
        start_lat = MIN_LAT
        start_lon = MIN_LON

    print("\nAll queries and bounding-box points processed!")
    print(f"Total unique places found: {len(discovered_places)}")
    print(f"Results in: {OUTPUT_CSV}")
    print(f"Checkpoint in: {CHECKPOINT_JSON}")

if __name__ == "__main__":
    main()
# Out:
# Warning: ../../data/preprocessed/scoring_indicators/community_centers_checkpoint.json is empty or invalid JSON. Using fresh checkpoint.
#
# === Searching for: 'community center' === (index: 0)
#
#   Searching around lat=30.3500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 60 new places added.
#
#   Searching around lat=30.3500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 21 new places added.
#
#   Searching around lat=30.3500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=30.3500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 13 new places added.
#
#   Searching around lat=30.3500, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.3500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.3500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 17 new places added.
#
#   Searching around lat=30.3500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 15 new places added.
#
#   Searching around lat=30.3500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 24 new places added.
#
#   Searching around lat=30.3500, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=30.3500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.3500, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.3500, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 15 new places added.
#
#   Searching around lat=30.3500, lon=-83.6500 for 'community center'
#    -> Found 14 results
#    -> 0 new places added.
#
#   Searching around lat=30.3500, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.3500, lon=-83.3500 for 'community center'
#    -> Found 53 results
#    -> 14 new places added.
#
#   Searching around lat=30.3500, lon=-83.2000 for 'community center'
#    -> Found 56 results
#    -> 5 new places added.
#
#   Searching around lat=30.3500, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=30.3500, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=30.3500, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=30.3500, lon=-82.6000 for 'community center'
#    -> Found 47 results
#    -> 4 new places added.
#
#   Searching around lat=30.3500, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.3500, lon=-82.3000 for 'community center'
#    -> Found 42 results
#    -> 5 new places added.
#
#   Searching around lat=30.3500, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 29 new places added.
#
#   Searching around lat=30.3500, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 32 new places added.
#
#   Searching around lat=30.3500, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 18 new places added.
#
#   Searching around lat=30.3500, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 21 new places added.
#
#   Searching around lat=30.3500, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 31 new places added.
#
#   Searching around lat=30.3500, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 20 new places added.
#
#   Searching around lat=30.3500, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=30.3500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.3500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=30.3500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 55 new places added.
#
#   Searching around lat=30.5000, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.5000, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.5000, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.5000, lon=-84.8500 for 'community center'
#    -> Found 35 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.5000, lon=-84.5500 for 'community center'
#    -> Found 51 results
#    -> 9 new places added.
#
#   Searching around lat=30.5000, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.5000, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=30.5000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=30.5000, lon=-83.9500 for 'community center'
#    -> Found 54 results
#    -> 5 new places added.
#
#   Searching around lat=30.5000, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.5000, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.5000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=30.5000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.5000, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.5000, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.5000, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.5000, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.5000, lon=-82.3000 for 'community center'
#    -> Found 32 results
#    -> 2 new places added.
#
#   Searching around lat=30.5000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.5000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.5000, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=30.5000, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.5000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.5000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.5000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.5000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.5000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.6500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=30.6500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=30.6500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.6500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.6500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.6500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.6500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.6500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.6500, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=30.6500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.6500, lon=-83.9500 for 'community center'
#    -> Found 42 results
#    -> 0 new places added.
#
#   Searching around lat=30.6500, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.6500, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.6500, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.6500, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=30.6500, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.6500, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.6500, lon=-82.4500 for 'community center'
#    -> Found 45 results
#    -> 1 new places added.
#
#   Searching around lat=30.6500, lon=-82.3000 for 'community center'
#    -> Found 33 results
#    -> 1 new places added.
#
#   Searching around lat=30.6500, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.6500, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=30.6500, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=30.6500, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.6500, lon=-81.2500 for 'community center'
#    -> Found 50 results
#    -> 4 new places added.
#
#   Searching around lat=30.6500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.6500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.6500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.8000, lon=-85.6000 for 'community center'
#    -> Found 45 results
#    -> 19 new places added.
#
#   Searching around lat=30.8000, lon=-85.4500 for 'community center'
#    -> Found 38 results
#    -> 2 new places added.
#
#   Searching around lat=30.8000, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.8000, lon=-85.1500 for 'community center'
#    -> Found 37 results
#    -> 2 new places added.
#
#   Searching around lat=30.8000, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.8000, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.8000, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.8000, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.8000, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.8000, lon=-84.2500 for 'community center'
#    -> Found 51 results
#    -> 8 new places added.
#
#   Searching around lat=30.8000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=30.8000, lon=-83.9500 for 'community center'
#    -> Found 29 results
#    -> 8 new places added.
#
#   Searching around lat=30.8000, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.8000, lon=-83.6500 for 'community center'
#    -> Found 58 results
#    -> 6 new places added.
#
#   Searching around lat=30.8000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.8000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 29 new places added.
#
#   Searching around lat=30.8000, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=30.8000, lon=-83.0500 for 'community center'
#    -> Found 33 results
#    -> 2 new places added.
#
#   Searching around lat=30.8000, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.8000, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.8000, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.8000, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.8000, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.8000, lon=-82.1500 for 'community center'
#    -> Found 53 results
#    -> 3 new places added.
#
#   Searching around lat=30.8000, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.8000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=30.8000, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=30.8000, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=30.8000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.8000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.8000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.8000, lon=-80.9500 for 'community center'
#    -> Found 47 results
#    -> 1 new places added.
#
#   Searching around lat=30.8000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-85.6000 for 'community center'
#    -> Found 53 results
#    -> 15 new places added.
#
#   Searching around lat=30.9500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=30.9500, lon=-85.3000 for 'community center'
#    -> Found 48 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.9500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-84.2500 for 'community center'
#    -> Found 55 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=30.9500, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=30.9500, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-83.0500 for 'community center'
#    -> Found 52 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-82.9000 for 'community center'
#    -> Found 29 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-82.6000 for 'community center'
#    -> Found 48 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-82.4500 for 'community center'
#    -> Found 55 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-82.3000 for 'community center'
#    -> Found 55 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=30.9500, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=30.9500, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=30.9500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=30.9500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=30.9500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=31.1000, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.1000, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.1000, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-85.0000 for 'community center'
#    -> Found 31 results
#    -> 1 new places added.
#
#   Searching around lat=31.1000, lon=-84.8500 for 'community center'
#    -> Found 27 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-84.7000 for 'community center'
#    -> Found 45 results
#    -> 1 new places added.
#
#   Searching around lat=31.1000, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=31.1000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.1000, lon=-83.8000 for 'community center'
#    -> Found 56 results
#    -> 14 new places added.
#
#   Searching around lat=31.1000, lon=-83.6500 for 'community center'
#    -> Found 48 results
#    -> 2 new places added.
#
#   Searching around lat=31.1000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.1000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=31.1000, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.1000, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.1000, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.1000, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=31.1000, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.1000, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.1000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.1000, lon=-82.0000 for 'community center'
#    -> Found 9 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.1000, lon=-81.5500 for 'community center'
#    -> Found 12 results
#    -> 2 new places added.
#
#   Searching around lat=31.1000, lon=-81.4000 for 'community center'
#    -> Found 11 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.1000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.1000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.1000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.2500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.2500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 22 new places added.
#
#   Searching around lat=31.2500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=31.2500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.2500, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.2500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.2500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.2500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.2500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.2500, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.2500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.2500, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-83.8000 for 'community center'
#    -> Found 57 results
#    -> 4 new places added.
#
#   Searching around lat=31.2500, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.2500, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=31.2500, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.2500, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.2500, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.2500, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=31.2500, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=31.2500, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=31.2500, lon=-82.1500 for 'community center'
#    -> Found 24 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-82.0000 for 'community center'
#    -> Found 14 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.2500, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.2500, lon=-81.5500 for 'community center'
#    -> Found 15 results
#    -> 2 new places added.
#
#   Searching around lat=31.2500, lon=-81.4000 for 'community center'
#    -> Found 14 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.2500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.2500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.2500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=31.4000, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-85.3000 for 'community center'
#    -> Found 58 results
#    -> 6 new places added.
#
#   Searching around lat=31.4000, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.4000, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.4000, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.4000, lon=-84.2500 for 'community center'
#    -> Found 58 results
#    -> 14 new places added.
#
#   Searching around lat=31.4000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-83.9500 for 'community center'
#    -> Found 37 results
#    -> 4 new places added.
#
#   Searching around lat=31.4000, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.4000, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=31.4000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.4000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.4000, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.4000, lon=-82.7500 for 'community center'
#    -> Found 46 results
#    -> 1 new places added.
#
#   Searching around lat=31.4000, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.4000, lon=-82.4500 for 'community center'
#    -> Found 15 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-82.0000 for 'community center'
#    -> Found 19 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.4000, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.4000, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.4000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.4000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-81.1000 for 'community center'
#    -> Found 54 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.4000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.5500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.5500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.5500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.5500, lon=-85.1500 for 'community center'
#    -> Found 56 results
#    -> 3 new places added.
#
#   Searching around lat=31.5500, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.5500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.5500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=31.5500, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 22 new places added.
#
#   Searching around lat=31.5500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=31.5500, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.5500, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.5500, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.5500, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.5500, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-83.0500 for 'community center'
#    -> Found 47 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=31.5500, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.5500, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.5500, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=31.5500, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.5500, lon=-82.1500 for 'community center'
#    -> Found 43 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=31.5500, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=31.5500, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.5500, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.5500, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.5500, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.5500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.5500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.7000, lon=-85.4500 for 'community center'
#    -> Found 52 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.7000, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.7000, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.7000, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.7000, lon=-84.4000 for 'community center'
#    -> Found 37 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.7000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.7000, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.7000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=31.7000, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=31.7000, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.7000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.7000, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-81.8500 for 'community center'
#    -> Found 53 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-81.7000 for 'community center'
#    -> Found 55 results
#    -> 5 new places added.
#
#   Searching around lat=31.7000, lon=-81.5500 for 'community center'
#    -> Found 34 results
#    -> 5 new places added.
#
#   Searching around lat=31.7000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#   Searching around lat=31.7000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.7000, lon=-80.8000 for 'community center'
#    -> Found 33 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.8500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=31.8500, lon=-85.0000 for 'community center'
#    -> Found 4 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-84.8500 for 'community center'
#    -> Found 57 results
#    -> 1 new places added.
#
#   Searching around lat=31.8500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.8500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.8500, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=31.8500, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=31.8500, lon=-83.6500 for 'community center'
#    -> Found 48 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-83.5000 for 'community center'
#    -> Found 49 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.8500, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=31.8500, lon=-82.7500 for 'community center'
#    -> Found 32 results
#    -> 3 new places added.
#
#   Searching around lat=31.8500, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=31.8500, lon=-82.1500 for 'community center'
#    -> Found 39 results
#    -> 3 new places added.
#
#   Searching around lat=31.8500, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=31.8500, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.8500, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=31.8500, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=31.8500, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 18 new places added.
#
#   Searching around lat=31.8500, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=31.8500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=31.8500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=31.8500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=32.0000, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=32.0000, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-85.3000 for 'community center'
#    -> Found 56 results
#    -> 4 new places added.
#
#   Searching around lat=32.0000, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=32.0000, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.0000, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=32.0000, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=32.0000, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=32.0000, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 20 new places added.
#
#   Searching around lat=32.0000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.0000, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=32.0000, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=32.0000, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.0000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-83.2000 for 'community center'
#    -> Found 39 results
#    -> 8 new places added.
#
#   Searching around lat=32.0000, lon=-83.0500 for 'community center'
#    -> Found 33 results
#    -> 2 new places added.
#
#   Searching around lat=32.0000, lon=-82.9000 for 'community center'
#    -> Found 48 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-82.7500 for 'community center'
#    -> Found 54 results
#    -> 1 new places added.
#
#   Searching around lat=32.0000, lon=-82.6000 for 'community center'
#    -> Found 32 results
#    -> 4 new places added.
#
#   Searching around lat=32.0000, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=32.0000, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=32.0000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.0000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.0000, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=32.0000, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.0000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=32.0000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=32.0000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=32.0000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=32.0000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=32.1500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=32.1500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=32.1500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.1500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=32.1500, lon=-85.0000 for 'community center'
#    -> Found 34 results
#    -> 4 new places added.
#
#   Searching around lat=32.1500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.1500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=32.1500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=32.1500, lon=-84.4000 for 'community center'
#    -> Found 60 results
# ...
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=34.7000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=34.7000, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=34.7000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=34.7000, lon=-81.7000 for 'community center'
#    -> Found 48 results
#    -> 5 new places added.
#
#   Searching around lat=34.7000, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.7000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=34.7000, lon=-81.2500 for 'community center'
#    -> Found 58 results
#    -> 22 new places added.
#
#   Searching around lat=34.7000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=34.7000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=34.7000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=34.8500, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=34.8500, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=34.8500, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=34.8500, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=34.8500, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=34.8500, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 15 new places added.
#
#   Searching around lat=34.8500, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=34.8500, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=34.8500, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=34.8500, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=34.8500, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=34.8500, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 9 new places added.
#
#   Searching around lat=34.8500, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=34.8500, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=34.8500, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=34.8500, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 17 new places added.
#
#   Searching around lat=34.8500, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=34.8500, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 8 new places added.
#
#   Searching around lat=34.8500, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 21 new places added.
#
#   Searching around lat=34.8500, lon=-81.8500 for 'community center'
#    -> Found 16 results
#    -> 0 new places added.
#
#   Searching around lat=34.8500, lon=-81.7000 for 'community center'
#    -> Found 59 results
#    -> 15 new places added.
#
#   Searching around lat=34.8500, lon=-81.5500 for 'community center'
#    -> Found 45 results
#    -> 3 new places added.
#
#   Searching around lat=34.8500, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=34.8500, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 16 new places added.
#
#   Searching around lat=34.8500, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 25 new places added.
#
#   Searching around lat=34.8500, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=34.8500, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=35.0000, lon=-85.6000 for 'community center'
#    -> Found 60 results
#    -> 18 new places added.
#
#   Searching around lat=35.0000, lon=-85.4500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=35.0000, lon=-85.3000 for 'community center'
#    -> Found 60 results
#    -> 17 new places added.
#
#   Searching around lat=35.0000, lon=-85.1500 for 'community center'
#    -> Found 60 results
#    -> 13 new places added.
#
#   Searching around lat=35.0000, lon=-85.0000 for 'community center'
#    -> Found 60 results
#    -> 14 new places added.
#
#   Searching around lat=35.0000, lon=-84.8500 for 'community center'
#    -> Found 60 results
#    -> 13 new places added.
#
#   Searching around lat=35.0000, lon=-84.7000 for 'community center'
#    -> Found 60 results
#    -> 4 new places added.
#
#   Searching around lat=35.0000, lon=-84.5500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=35.0000, lon=-84.4000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=35.0000, lon=-84.2500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=35.0000, lon=-84.1000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=35.0000, lon=-83.9500 for 'community center'
#    -> Found 60 results
#    -> 3 new places added.
#
#   Searching around lat=35.0000, lon=-83.8000 for 'community center'
#    -> Found 60 results
#    -> 7 new places added.
#
#   Searching around lat=35.0000, lon=-83.6500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=35.0000, lon=-83.5000 for 'community center'
#    -> Found 60 results
#    -> 15 new places added.
#
#   Searching around lat=35.0000, lon=-83.3500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=35.0000, lon=-83.2000 for 'community center'
#    -> Found 60 results
#    -> 16 new places added.
#
#   Searching around lat=35.0000, lon=-83.0500 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=35.0000, lon=-82.9000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=35.0000, lon=-82.7500 for 'community center'
#    -> Found 60 results
#    -> 0 new places added.
#
#   Searching around lat=35.0000, lon=-82.6000 for 'community center'
#    -> Found 60 results
#    -> 1 new places added.
#
#   Searching around lat=35.0000, lon=-82.4500 for 'community center'
#    -> Found 60 results
#    -> 5 new places added.
#
#   Searching around lat=35.0000, lon=-82.3000 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=35.0000, lon=-82.1500 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=35.0000, lon=-82.0000 for 'community center'
#    -> Found 60 results
#    -> 13 new places added.
#
#   Searching around lat=35.0000, lon=-81.8500 for 'community center'
#    -> Found 60 results
#    -> 13 new places added.
#
#   Searching around lat=35.0000, lon=-81.7000 for 'community center'
#    -> Found 60 results
#    -> 12 new places added.
#
#   Searching around lat=35.0000, lon=-81.5500 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=35.0000, lon=-81.4000 for 'community center'
#    -> Found 60 results
#    -> 6 new places added.
#
#   Searching around lat=35.0000, lon=-81.2500 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=35.0000, lon=-81.1000 for 'community center'
#    -> Found 60 results
#    -> 2 new places added.
#
#   Searching around lat=35.0000, lon=-80.9500 for 'community center'
#    -> Found 60 results
#    -> 10 new places added.
#
#   Searching around lat=35.0000, lon=-80.8000 for 'community center'
#    -> Found 60 results
#    -> 11 new places added.
#
#
# === Searching for: 'recreation center' === (index: 1)
#
#   Searching around lat=30.3500, lon=-85.6000 for 'recreation center'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 195
#     192     print(f"Checkpoint in: {CHECKPOINT_JSON}")
#     194 if __name__ == "__main__":
# --> 195     main()
#
# Cell In[6], line 131, in main()
#     129 while lon <= MAX_LON + 0.000001:
#     130     print(f"  Searching around lat={lat:.4f}, lon={lon:.4f} for '{query}'")
# --> 131     results = text_search(query, lat, lon, API_KEY)
#     132     print(f"   -> Found {len(results)} results")
#     134     # Process results
#
# Cell In[6], line 84, in text_search(query, lat, lon, api_key)
#      76 params = {
#      77     "query": query,
#      78     "location": f"{lat},{lon}",
#      79     "radius": RADIUS,
#      80     "key": api_key
#      81 }
#      83 while True:
# ---> 84     resp = requests.get(url, params=params)
#      85     data = resp.json()
#      87     if data.get("status") not in ("OK", "ZERO_RESULTS"):
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/anaconda3/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/homebrew/anaconda3/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/anaconda3/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
